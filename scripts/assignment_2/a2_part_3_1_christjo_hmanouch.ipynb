# %%
"""
*******************************************************************************

Project: RL, assignment 2
File: warehouse_robot_dqn.ipynb
Author: Hamid Manouchehri
Email: hmanouch@buffalo.edu
Date: Mar 17, 2025

Description:

License:
This script is licensed under the MIT License.
You may obtain a copy of the License at
    https://opensource.org/licenses/MIT

SPDX-License-Identifier: MIT

Disclaimer:
This software is provided "as is", without warranty of any kind, express or
implied, including but not limited to the warranties of merchantability,
fitness for a particular purpose, and noninfringement. In no event shall the
authors be liable for any claim, damages, or other liability, whether in an
action of contract, tort, or otherwise, arising from, out of, or in connection
with the software or the use or other dealings in the software.

*******************************************************************************
"""
# Out:
# '\n*******************************************************************************\n\nProject: RL, assignment 2\nFile: warehouse_robot_dqn.ipynb\nAuthor: Hamid Manouchehri\nEmail: hmanouch@buffalo.edu\nDate: Mar 17, 2025\n\nDescription:\n\nLicense:\nThis script is licensed under the MIT License.\nYou may obtain a copy of the License at\n    https://opensource.org/licenses/MIT\n\nSPDX-License-Identifier: MIT\n\nDisclaimer:\nThis software is provided "as is", without warranty of any kind, express or\nimplied, including but not limited to the warranties of merchantability,\nfitness for a particular purpose, and noninfringement. In no event shall the\nauthors be liable for any claim, damages, or other liability, whether in an\naction of contract, tort, or otherwise, arising from, out of, or in connection\nwith the software or the use or other dealings in the software.\n\n*******************************************************************************\n'

# %%
#!/usr/bin/env python3

import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
import matplotlib.colors as mcolors
from IPython.display import clear_output
# from environment import WumpusWorldEnvironment
import torch
import torch.nn as nn
import torch.nn.functional as F
import cv2
from collections import deque
import random
import torch.optim as optim
import os

# %%
################################
## Custom Function Definition ##
################################
def save_plot_as_img(png_plot_name, dir):
    """ Call this function after plt.plot(...)"""
    
    save_path = os.path.join(dir, png_plot_name)
    plt.savefig(save_path, dpi=300, bbox_inches='tight')

    print(f"Plot saved at: {save_path}")

# %%
grid_size = 6
grid = np.ones((grid_size, grid_size, 3))
# Define grid size
grid_size = 6  # 6x6 grid

# Initialize grid with default background (White = 4)
grid = np.full((grid_size, grid_size), 1, dtype=int)  # Default to background

# Define agent and goal positions
init_agent_pos = [0, 0]  # Start position
goal_pos = [5, 5]  # Goal position

# Define integer-based color mapping
rgb_colors = {
    "black": 0,   # Agent
    "white": 1,   # Goal
    "red": 2,     # Trap
    "blue": 3,    # Water
    "green": 4,   # Background
    "gray": 5     # Obstacle
}

# Define color list for visualization
color_map = {
    0: "black",
    1: "white",
    2: "red",
    3: "blue",
    4: "green",
    5: "gray"
}

agent_obj_state = {
    0: "no_obj",
    1: "have_obj"
}

# Assign integer values to the grid
grid[tuple(init_agent_pos)] = rgb_colors["black"]  # Agent
grid[tuple(goal_pos)] = rgb_colors["green"]  # Goal

# Create a colormap using actual colors
cmap = mcolors.ListedColormap([color_map[i] for i in range(len(color_map))])

for i in range(6):  # rows
    for j in range(6):  # columns
        text = ""
        if [i, j] == init_agent_pos:
            text = "Agent"
        elif [i, j] == goal_pos:
            text = "Goal"
        
        # Only annotate if there is text to display
        if text:
            plt.text(j, i, text, ha="center", va="center", color="white", fontsize=8)


# Display the grid with correct colors
plt.imshow(grid, cmap=cmap, vmin=0, vmax=len(color_map) - 1)
plt.title("Grid Environment")
plt.show()

# %% [markdown]
# ### Grid World Environment: Warehouse Robot

# %%
class GridEnvironment(gym.Env):
    metadata = {'render.modes': []}
    
    def __init__(self, max_timesteps):
        # Observation: [carry_flag, x, y]
        # carry_flag: 0 or 1, x: 0-5, y: 0-5
        self.observation_space = spaces.MultiDiscrete([2, 6, 6])
        self.action_space = spaces.Discrete(4)
        self.max_timesteps = max_timesteps
        self.reward = 0
        
        self.timestep = 0
        self.agent_carry_obj = False
        self.agent_pos = [0, 0]
        self.goal_pos = [5, 5]
        self.object_pos = [1, 2]
        self.obstacle_1_pos = [2, 2]
        
        self.state = np.ones((6,6))
        self.state[tuple(self.agent_pos)] = rgb_colors["black"]
        self.state[tuple(self.goal_pos)] = rgb_colors["green"]
        self.state[tuple(self.object_pos)] = rgb_colors["blue"]
        self.state[tuple(self.obstacle_1_pos)] = rgb_colors["red"]
    
    def reset(self, **kwargs):
        self.agent_carry_obj = False
        self.agent_pos = [0, 0]
        self.goal_pos = [5, 5]
        self.object_pos = [1, 2]
        self.obstacle_1_pos = [2, 2]
        self.reward = 0
        self.timestep = 0
        self.state = np.ones((6,6))
        self.state[tuple(self.agent_pos)] = rgb_colors["black"]
        self.state[tuple(self.goal_pos)] = rgb_colors["green"]
        self.state[tuple(self.object_pos)] = rgb_colors["blue"]
        self.state[tuple(self.obstacle_1_pos)] = rgb_colors["red"]
        # Return observation as [carry_flag, x, y]
        observation = np.array([int(self.agent_carry_obj)] + self.agent_pos)
        info = {}
        return observation, info

    def pick_up_obj(self):
        self.state[tuple(self.object_pos)] = rgb_colors["white"]
        self.agent_carry_obj = True

    def drop_off_obj(self):
        self.state[tuple(self.goal_pos)] = rgb_colors["white"]
        self.agent_carry_obj = False

    def step(self, action):
        self.reward -= 1
        terminated = False
        
        # Compute potential new position based on action.
        new_agent_pos = self.agent_pos.copy()
        if action == 0:  # down
            new_agent_pos[0] += 1
        elif action == 1:  # up
            new_agent_pos[0] -= 1
        elif action == 2:  # right
            new_agent_pos[1] += 1
        elif action == 3:  # left
            new_agent_pos[1] -= 1
            
        # Ensure new position is within bounds.
        new_agent_pos = np.clip(new_agent_pos, 0, 5).tolist()
        
        # Obstacle avoidance: If new position equals the obstacle, apply penalty and do not move.
        if np.array_equal(new_agent_pos, self.obstacle_1_pos):
            self.reward -= 25
        else:
            self.agent_pos = new_agent_pos
        
        # Update grid state.
        self.state = np.ones((6,6))
        self.state[tuple(self.agent_pos)] = rgb_colors["black"]
        self.state[tuple(self.goal_pos)] = rgb_colors["green"]
        if not self.agent_carry_obj:
            self.state[tuple(self.object_pos)] = rgb_colors["blue"]
        self.state[tuple(self.obstacle_1_pos)] = rgb_colors["red"]
        
        # Create observation: [carry_flag, x, y]
        observation = np.array([int(self.agent_carry_obj)] + self.agent_pos)
        
        # Check for pickup.
        if np.array_equal(self.agent_pos, self.object_pos) and not self.agent_carry_obj:
            self.pick_up_obj()
            self.reward += 25
            self.state[tuple(self.object_pos)] = rgb_colors["black"]
        
        # Check for dropoff.
        if np.array_equal(self.agent_pos, self.goal_pos) and self.agent_carry_obj:
            self.drop_off_obj()
            self.reward += 100
            terminated = True
            self.state[tuple(self.goal_pos)] = rgb_colors["black"]
        
        self.timestep += 1
        if self.timestep >= self.max_timesteps:
            terminated = True
        
        truncated = np.all((np.asarray(self.agent_pos) >= 0) & (np.asarray(self.agent_pos) <= 5))
        info = {}
        return observation, self.reward, terminated, truncated, info

    def render(self):
        # Optional: A simple rendering function for debugging.
        cmap = mcolors.ListedColormap([color_map[i] for i in range(len(color_map))])
        plt.imshow(self.state, cmap=cmap, vmin=0, vmax=len(color_map)-1)
        for i in range(6):
            for j in range(6):
                label = ""
                if np.array_equal([i, j], self.agent_pos):
                    label = "Agent"
                elif np.array_equal([i, j], self.goal_pos):
                    label = "Goal"
                elif np.array_equal([i, j], self.object_pos):
                    label = "Obj"
                elif np.array_equal([i, j], self.obstacle_1_pos):
                    label = "Obs"
                if label:
                    plt.text(j, i, label, ha="center", va="center", color="white", fontsize=8)
        plt.title("Grid Environment")
        plt.show()

# %% [markdown]
# ### DQN, Observation Type: Vecot

# %%
num_of_episodes = 1000
max_steps = 50
learning_rate = 1e-2
min_epsilon = 0.1
epsilon_decay_factor = 0.998
batch_size = 32
gamma = 0.9
C = 20

# Define your neural network architecture.
class NeuralNetwork(nn.Module):

    def __init__(self):
        super(NeuralNetwork, self).__init__()

        self.fc1 = nn.Linear(3, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 4)


    def forward(self, x):

        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x


# DQN Agent class
class DQN():
    def __init__(self, env):
        self.env = env
        self.D = deque([], maxlen=1000)  # replay memory
        self.batch_size = batch_size

        self.Q_policy = NeuralNetwork()  # main network
        self.Q_prime = NeuralNetwork()   # target network
        self.Q_prime.load_state_dict(self.Q_policy.state_dict())

        self.init_epsilon = 1.0
        self.rewards = []
        self.epsilon_arr = []
        self.total_steps = 0

        self.criterion = nn.MSELoss()
        self.optimizer = optim.AdamW(self.Q_policy.parameters(), lr=learning_rate)

    def epsilon_greedy(self, prev_state):
        if self.init_epsilon > np.random.random():
            action = self.env.action_space.sample()
        else:
            # prev_state is a 6x6 grayscale image.
            state_tensor = torch.tensor(prev_state, dtype=torch.float32).unsqueeze(0)
            # The forward pass will flatten the image.
            q_values = self.Q_policy(state_tensor)
            action = torch.argmax(q_values).item()
        return action

    def train_model(self):
        if len(self.D) < self.batch_size:
            return

        batch = random.sample(self.D, self.batch_size)

        # Convert batch elements to tensors.
        # Here, s[0] and s[3] are 6x6 images.
        states = torch.tensor([s[0] for s in batch], dtype=torch.float32)
        actions = torch.tensor([s[1] for s in batch], dtype=torch.long).unsqueeze(1)
        rewards = torch.tensor([s[2] for s in batch], dtype=torch.float32)
        next_states = torch.tensor([s[3] for s in batch], dtype=torch.float32)
        dones = torch.tensor([s[4] for s in batch], dtype=torch.float32)

        # Flatten the states to [batch_size, 36] (if not already flattened).
        states = states.view(states.size(0), -1)
        next_states = next_states.view(next_states.size(0), -1)

        # Get the predicted Q-values for the actions taken.
        current_q_values = self.Q_policy(states).gather(1, actions)

        # Compute the target Q-values using the target network.
        next_q_values = self.Q_prime(next_states).max(1)[0]
        target_q_values = rewards + (1 - dones) * gamma * next_q_values
        target_q_values = target_q_values.unsqueeze(1)

        loss = self.criterion(current_q_values, target_q_values)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def train(self):
        for episode in range(num_of_episodes):
            prev_state, info = self.env.reset()
            ep_reward = 0

            for t in range(max_steps):
                action = self.epsilon_greedy(prev_state)
                next_state, reward, terminated, truncated, info = self.env.step(action)
                ep_reward += reward

                done = terminated  # or terminated or truncated
                self.D.append((prev_state, action, reward, next_state, done))
                self.train_model()

                prev_state = next_state
                self.total_steps += 1

                if t % C == 0:
                    self.Q_prime.load_state_dict(self.Q_policy.state_dict())

                if done:
                    break

            self.rewards.append(ep_reward)
            self.init_epsilon = max(min_epsilon, self.init_epsilon * epsilon_decay_factor)
            self.epsilon_arr.append(self.init_epsilon)
            print(f"Episode {episode}, Reward: {ep_reward}, Epsilon: {self.init_epsilon}")

        print("Training complete.")
        return self.rewards

dir_to_save_data = "/home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/"

env = GridEnvironment(max_timesteps=500)
dqn_agent = DQN(env)
training_rewards = dqn_agent.train()

plt.figure(1)
plt.plot(dqn_agent.rewards)
save_plot_as_img('dqn_warehouse_robot_reward_per_episode.png', dir_to_save_data)

plt.figure(2)
plt.plot(dqn_agent.epsilon_arr)
save_plot_as_img('dqn_warehouse_robot_epsilon_decay.png', dir_to_save_data)
# Out:
# Episode 0, Reward: -100, Epsilon: 0.998
# Episode 1, Reward: -1250, Epsilon: 0.996004
# Episode 2, Reward: -1650, Epsilon: 0.994011992
# Episode 3, Reward: -1275, Epsilon: 0.992023968016
# Episode 4, Reward: -125, Epsilon: 0.990039920079968
# Episode 5, Reward: -225, Epsilon: 0.9880598402398081
# Episode 6, Reward: 195, Epsilon: 0.9860837205593285
# Episode 7, Reward: -925, Epsilon: 0.9841115531182099
# Episode 8, Reward: -625, Epsilon: 0.9821433300119734
# Episode 9, Reward: -325, Epsilon: 0.9801790433519495
# Episode 10, Reward: -1050, Epsilon: 0.9782186852652456
# Episode 11, Reward: -3950, Epsilon: 0.976262247894715
# Episode 12, Reward: -275, Epsilon: 0.9743097233989256
# Episode 13, Reward: -1250, Epsilon: 0.9723611039521278
# Episode 14, Reward: -1075, Epsilon: 0.9704163817442236
# Episode 15, Reward: -2175, Epsilon: 0.9684755489807352
# Episode 16, Reward: -2300, Epsilon: 0.9665385978827737
# Episode 17, Reward: -730, Epsilon: 0.9646055206870082
# Episode 18, Reward: -3950, Epsilon: 0.9626763096456342
# Episode 19, Reward: -4550, Epsilon: 0.9607509570263429
# Episode 20, Reward: -300, Epsilon: 0.9588294551122902
# Episode 21, Reward: 64, Epsilon: 0.9569117962020657
# Episode 22, Reward: -1003, Epsilon: 0.9549979726096616
# Episode 23, Reward: -3100, Epsilon: 0.9530879766644422
# Episode 24, Reward: -386, Epsilon: 0.9511818007111134
# Episode 25, Reward: -1250, Epsilon: 0.9492794371096911
# Episode 26, Reward: -1275, Epsilon: 0.9473808782354717
# Episode 27, Reward: -1275, Epsilon: 0.9454861164790007
# Episode 28, Reward: 240, Epsilon: 0.9435951442460427
# Episode 29, Reward: -2200, Epsilon: 0.9417079539575507
# Episode 30, Reward: -2350, Epsilon: 0.9398245380496356
# Episode 31, Reward: -1125, Epsilon: 0.9379448889735363
# Episode 32, Reward: -3700, Epsilon: 0.9360689991955893
# Episode 33, Reward: -3066, Epsilon: 0.9341968611971981
# Episode 34, Reward: -1000, Epsilon: 0.9323284674748037
# Episode 35, Reward: -900, Epsilon: 0.930463810539854
# Episode 36, Reward: -2425, Epsilon: 0.9286028829187744
# Episode 37, Reward: -1200, Epsilon: 0.9267456771529368
# Episode 38, Reward: -1350, Epsilon: 0.9248921857986309
# Episode 39, Reward: -2175, Epsilon: 0.9230424014270336
# Episode 40, Reward: -1675, Epsilon: 0.9211963166241796
# Episode 41, Reward: -1450, Epsilon: 0.9193539239909312
# Episode 42, Reward: -2875, Epsilon: 0.9175152161429493
# Episode 43, Reward: -1275, Epsilon: 0.9156801857106633
# Episode 44, Reward: -1575, Epsilon: 0.913848825339242
# Episode 45, Reward: -1275, Epsilon: 0.9120211276885636
# Episode 46, Reward: -1050, Epsilon: 0.9101970854331864
# Episode 47, Reward: -1275, Epsilon: 0.9083766912623201
# Episode 48, Reward: -3675, Epsilon: 0.9065599378797955
# Episode 49, Reward: -1675, Epsilon: 0.9047468180040359
# Episode 50, Reward: -575, Epsilon: 0.9029373243680279
# Episode 51, Reward: -725, Epsilon: 0.9011314497192918
# Episode 52, Reward: -2300, Epsilon: 0.8993291868198532
# Episode 53, Reward: -5850, Epsilon: 0.8975305284462135
# Episode 54, Reward: -970, Epsilon: 0.8957354673893211
# Episode 55, Reward: -700, Epsilon: 0.8939439964545425
# Episode 56, Reward: -1725, Epsilon: 0.8921561084616334
# Episode 57, Reward: -275, Epsilon: 0.8903717962447101
# Episode 58, Reward: -1275, Epsilon: 0.8885910526522206
# Episode 59, Reward: -2775, Epsilon: 0.8868138705469162
# Episode 60, Reward: -3100, Epsilon: 0.8850402428058224
# Episode 61, Reward: -400, Epsilon: 0.8832701623202107
# Episode 62, Reward: -650, Epsilon: 0.8815036219955703
# Episode 63, Reward: -250, Epsilon: 0.8797406147515792
# Episode 64, Reward: -225, Epsilon: 0.877981133522076
# Episode 65, Reward: -1250, Epsilon: 0.8762251712550319
# Episode 66, Reward: -1275, Epsilon: 0.8744727209125218
# Episode 67, Reward: -1250, Epsilon: 0.8727237754706968
# Episode 68, Reward: -300, Epsilon: 0.8709783279197554
# Episode 69, Reward: -625, Epsilon: 0.8692363712639158
# Episode 70, Reward: -200, Epsilon: 0.867497898521388
# Episode 71, Reward: -875, Epsilon: 0.8657629027243453
# Episode 72, Reward: -1250, Epsilon: 0.8640313769188966
# Episode 73, Reward: -200, Epsilon: 0.8623033141650589
# Episode 74, Reward: -1950, Epsilon: 0.8605787075367288
# Episode 75, Reward: -300, Epsilon: 0.8588575501216553
# Episode 76, Reward: -1075, Epsilon: 0.857139835021412
# Episode 77, Reward: -1250, Epsilon: 0.8554255553513692
# Episode 78, Reward: -225, Epsilon: 0.8537147042406664
# Episode 79, Reward: -1250, Epsilon: 0.8520072748321851
# Episode 80, Reward: -150, Epsilon: 0.8503032602825207
# Episode 81, Reward: -1975, Epsilon: 0.8486026537619556
# Episode 82, Reward: -2875, Epsilon: 0.8469054484544317
# Episode 83, Reward: 65, Epsilon: 0.8452116375575228
# Episode 84, Reward: -75, Epsilon: 0.8435212142824078
# Episode 85, Reward: -125, Epsilon: 0.841834171853843
# Episode 86, Reward: -575, Epsilon: 0.8401505035101353
# Episode 87, Reward: -1400, Epsilon: 0.838470202503115
# Episode 88, Reward: -700, Epsilon: 0.8367932620981088
# Episode 89, Reward: -1525, Epsilon: 0.8351196755739125
# Episode 90, Reward: 25, Epsilon: 0.8334494362227647
# Episode 91, Reward: 274, Epsilon: 0.8317825373503192
# Episode 92, Reward: -1466, Epsilon: 0.8301189722756185
# Episode 93, Reward: -2650, Epsilon: 0.8284587343310672
# Episode 94, Reward: 299, Epsilon: 0.8268018168624051
# Episode 95, Reward: -1075, Epsilon: 0.8251482132286803
# Episode 96, Reward: -175, Epsilon: 0.823497916802223
# Episode 97, Reward: -1250, Epsilon: 0.8218509209686186
# Episode 98, Reward: -2310, Epsilon: 0.8202072191266814
# Episode 99, Reward: -900, Epsilon: 0.818566804688428
# Episode 100, Reward: -375, Epsilon: 0.8169296710790511
# Episode 101, Reward: -1250, Epsilon: 0.815295811736893
# Episode 102, Reward: -200, Epsilon: 0.8136652201134192
# Episode 103, Reward: -2450, Epsilon: 0.8120378896731923
# Episode 104, Reward: 184, Epsilon: 0.8104138138938459
# Episode 105, Reward: -250, Epsilon: 0.8087929862660582
# Episode 106, Reward: -750, Epsilon: 0.8071754002935261
# Episode 107, Reward: -1200, Epsilon: 0.805561049492939
# Episode 108, Reward: -325, Epsilon: 0.8039499273939532
# Episode 109, Reward: -2225, Epsilon: 0.8023420275391653
# Episode 110, Reward: -600, Epsilon: 0.800737343484087
# Episode 111, Reward: -1325, Epsilon: 0.7991358687971188
# Episode 112, Reward: 234, Epsilon: 0.7975375970595246
# Episode 113, Reward: -450, Epsilon: 0.7959425218654056
# Episode 114, Reward: -2175, Epsilon: 0.7943506368216747
# Episode 115, Reward: -2975, Epsilon: 0.7927619355480314
# Episode 116, Reward: -1575, Epsilon: 0.7911764116769353
# Episode 117, Reward: -1275, Epsilon: 0.7895940588535815
# Episode 118, Reward: -2675, Epsilon: 0.7880148707358743
# Episode 119, Reward: -1325, Epsilon: 0.7864388409944025
# Episode 120, Reward: -100, Epsilon: 0.7848659633124138
# Episode 121, Reward: -75, Epsilon: 0.783296231385789
# Episode 122, Reward: -1341, Epsilon: 0.7817296389230174
# Episode 123, Reward: -4525, Epsilon: 0.7801661796451713
# Episode 124, Reward: -1451, Epsilon: 0.778605847285881
# Episode 125, Reward: 265, Epsilon: 0.7770486355913092
# Episode 126, Reward: -2025, Epsilon: 0.7754945383201266
# Episode 127, Reward: -150, Epsilon: 0.7739435492434863
# Episode 128, Reward: 55, Epsilon: 0.7723956621449993
# Episode 129, Reward: -1831, Epsilon: 0.7708508708207094
# Episode 130, Reward: -1450, Epsilon: 0.769309169079068
# Episode 131, Reward: -2250, Epsilon: 0.7677705507409098
# Episode 132, Reward: -378, Epsilon: 0.766235009639428
# Episode 133, Reward: -1050, Epsilon: 0.7647025396201492
# Episode 134, Reward: -1175, Epsilon: 0.763173134540909
# Episode 135, Reward: -100, Epsilon: 0.7616467882718272
# Episode 136, Reward: -1250, Epsilon: 0.7601234946952835
# Episode 137, Reward: -325, Epsilon: 0.7586032477058929
# Episode 138, Reward: -3175, Epsilon: 0.7570860412104812
# Episode 139, Reward: -500, Epsilon: 0.7555718691280602
# Episode 140, Reward: 97, Epsilon: 0.7540607253898041
# Episode 141, Reward: -125, Epsilon: 0.7525526039390245
# Episode 142, Reward: -100, Epsilon: 0.7510474987311464
# Episode 143, Reward: -1150, Epsilon: 0.7495454037336841
# Episode 144, Reward: -550, Epsilon: 0.7480463129262167
# Episode 145, Reward: -350, Epsilon: 0.7465502203003642
# Episode 146, Reward: -750, Epsilon: 0.7450571198597635
# Episode 147, Reward: -275, Epsilon: 0.743567005620044
# Episode 148, Reward: -100, Epsilon: 0.7420798716088038
# Episode 149, Reward: -450, Epsilon: 0.7405957118655863
# Episode 150, Reward: -1275, Epsilon: 0.7391145204418551
# Episode 151, Reward: -175, Epsilon: 0.7376362914009714
# Episode 152, Reward: -100, Epsilon: 0.7361610188181695
# Episode 153, Reward: -1250, Epsilon: 0.7346886967805332
# Episode 154, Reward: -1250, Epsilon: 0.733219319386972
# Episode 155, Reward: 250, Epsilon: 0.7317528807481981
# Episode 156, Reward: -2275, Epsilon: 0.7302893749867018
# Episode 157, Reward: -650, Epsilon: 0.7288287962367284
# Episode 158, Reward: -2175, Epsilon: 0.727371138644255
# Episode 159, Reward: -875, Epsilon: 0.7259163963669665
# Episode 160, Reward: 185, Epsilon: 0.7244645635742325
# Episode 161, Reward: -1350, Epsilon: 0.723015634447084
# Episode 162, Reward: -976, Epsilon: 0.7215696031781899
# Episode 163, Reward: -3275, Epsilon: 0.7201264639718334
# Episode 164, Reward: -1061, Epsilon: 0.7186862110438897
# Episode 165, Reward: -875, Epsilon: 0.717248838621802
# Episode 166, Reward: -1975, Epsilon: 0.7158143409445584
# Episode 167, Reward: -1975, Epsilon: 0.7143827122626694
# Episode 168, Reward: -2250, Epsilon: 0.7129539468381441
# Episode 169, Reward: -1425, Epsilon: 0.7115280389444678
# Episode 170, Reward: -2325, Epsilon: 0.7101049828665789
# Episode 171, Reward: -146, Epsilon: 0.7086847729008457
# Episode 172, Reward: -441, Epsilon: 0.707267403355044
# Episode 173, Reward: -1200, Epsilon: 0.705852868548334
# Episode 174, Reward: -1200, Epsilon: 0.7044411628112373
# Episode 175, Reward: -1780, Epsilon: 0.7030322804856147
# Episode 176, Reward: -256, Epsilon: 0.7016262159246435
# Episode 177, Reward: 264, Epsilon: 0.7002229634927942
# Episode 178, Reward: 304, Epsilon: 0.6988225175658086
# Episode 179, Reward: -670, Epsilon: 0.697424872530677
# Episode 180, Reward: 60, Epsilon: 0.6960300227856157
# Episode 181, Reward: -350, Epsilon: 0.6946379627400444
# Episode 182, Reward: -2825, Epsilon: 0.6932486868145643
# Episode 183, Reward: -815, Epsilon: 0.6918621894409351
# Episode 184, Reward: -706, Epsilon: 0.6904784650620532
# Episode 185, Reward: 315, Epsilon: 0.6890975081319292
# Episode 186, Reward: -675, Epsilon: 0.6877193131156653
# Episode 187, Reward: 255, Epsilon: 0.6863438744894339
# Episode 188, Reward: -371, Epsilon: 0.684971186740455
# Episode 189, Reward: 245, Epsilon: 0.6836012443669741
# Episode 190, Reward: -1825, Epsilon: 0.6822340418782402
# Episode 191, Reward: -240, Epsilon: 0.6808695737944838
# Episode 192, Reward: -1466, Epsilon: 0.6795078346468948
# Episode 193, Reward: -1980, Epsilon: 0.678148818977601
# Episode 194, Reward: -391, Epsilon: 0.6767925213396458
# Episode 195, Reward: 169, Epsilon: 0.6754389362969666
# Episode 196, Reward: -196, Epsilon: 0.6740880584243727
# Episode 197, Reward: -400, Epsilon: 0.6727398823075239
# Episode 198, Reward: -425, Epsilon: 0.6713944025429088
# Episode 199, Reward: 219, Epsilon: 0.670051613737823
# Episode 200, Reward: -1275, Epsilon: 0.6687115105103473
# Episode 201, Reward: 40, Epsilon: 0.6673740874893266
# Episode 202, Reward: -778, Epsilon: 0.6660393393143479
# Episode 203, Reward: -275, Epsilon: 0.6647072606357192
# Episode 204, Reward: -695, Epsilon: 0.6633778461144477
# Episode 205, Reward: -200, Epsilon: 0.6620510904222189
# Episode 206, Reward: -1575, Epsilon: 0.6607269882413744
# Episode 207, Reward: -600, Epsilon: 0.6594055342648917
# Episode 208, Reward: -550, Epsilon: 0.6580867231963619
# Episode 209, Reward: -250, Epsilon: 0.6567705497499692
# Episode 210, Reward: -625, Epsilon: 0.6554570086504692
# Episode 211, Reward: 5, Epsilon: 0.6541460946331682
# Episode 212, Reward: -275, Epsilon: 0.6528378024439019
# Episode 213, Reward: -325, Epsilon: 0.6515321268390141
# Episode 214, Reward: -775, Epsilon: 0.6502290625853361
# Episode 215, Reward: -2325, Epsilon: 0.6489286044601654
# Episode 216, Reward: -75, Epsilon: 0.6476307472512451
# Episode 217, Reward: -675, Epsilon: 0.6463354857567426
# Episode 218, Reward: -1850, Epsilon: 0.6450428147852291
# Episode 219, Reward: -1325, Epsilon: 0.6437527291556586
# Episode 220, Reward: -75, Epsilon: 0.6424652236973473
# Episode 221, Reward: -1325, Epsilon: 0.6411802932499525
# Episode 222, Reward: -125, Epsilon: 0.6398979326634526
# Episode 223, Reward: -2625, Epsilon: 0.6386181367981257
# Episode 224, Reward: -1250, Epsilon: 0.6373409005245295
# Episode 225, Reward: -2150, Epsilon: 0.6360662187234805
# Episode 226, Reward: -1950, Epsilon: 0.6347940862860335
# Episode 227, Reward: -2600, Epsilon: 0.6335244981134615
# Episode 228, Reward: -1550, Epsilon: 0.6322574491172346
# Episode 229, Reward: -1900, Epsilon: 0.6309929342190002
# Episode 230, Reward: -695, Epsilon: 0.6297309483505622
# Episode 231, Reward: -1275, Epsilon: 0.6284714864538611
# Episode 232, Reward: -500, Epsilon: 0.6272145434809534
# Episode 233, Reward: -625, Epsilon: 0.6259601143939915
# Episode 234, Reward: -65, Epsilon: 0.6247081941652035
# Episode 235, Reward: 322, Epsilon: 0.6234587777768731
# Episode 236, Reward: 34, Epsilon: 0.6222118602213194
# Episode 237, Reward: -2525, Epsilon: 0.6209674365008767
# Episode 238, Reward: -1600, Epsilon: 0.619725501627875
# Episode 239, Reward: -1270, Epsilon: 0.6184860506246193
# Episode 240, Reward: -1275, Epsilon: 0.61724907852337
# Episode 241, Reward: -325, Epsilon: 0.6160145803663232
# Episode 242, Reward: -1275, Epsilon: 0.6147825512055906
# Episode 243, Reward: 340, Epsilon: 0.6135529861031793
# Episode 244, Reward: -471, Epsilon: 0.612325880130973
# Episode 245, Reward: -450, Epsilon: 0.611101228370711
# Episode 246, Reward: -78, Epsilon: 0.6098790259139696
# Episode 247, Reward: -1200, Epsilon: 0.6086592678621416
# Episode 248, Reward: -145, Epsilon: 0.6074419493264174
# Episode 249, Reward: 344, Epsilon: 0.6062270654277645
# Episode 250, Reward: 259, Epsilon: 0.6050146112969089
# Episode 251, Reward: 247, Epsilon: 0.6038045820743151
# Episode 252, Reward: -436, Epsilon: 0.6025969729101665
# Episode 253, Reward: -2175, Epsilon: 0.6013917789643461
# Episode 254, Reward: -50, Epsilon: 0.6001889954064175
# Episode 255, Reward: -475, Epsilon: 0.5989886174156046
# Episode 256, Reward: -56, Epsilon: 0.5977906401807734
# Episode 257, Reward: -955, Epsilon: 0.5965950589004119
# Episode 258, Reward: 272, Epsilon: 0.595401868782611
# Episode 259, Reward: -153, Epsilon: 0.5942110650450458
# Episode 260, Reward: -351, Epsilon: 0.5930226429149558
# Episode 261, Reward: 299, Epsilon: 0.5918365976291259
# Episode 262, Reward: -1250, Epsilon: 0.5906529244338676
# Episode 263, Reward: -1503, Epsilon: 0.5894716185849999
# Episode 264, Reward: -555, Epsilon: 0.5882926753478298
# Episode 265, Reward: -435, Epsilon: 0.5871160899971342
# Episode 266, Reward: -106, Epsilon: 0.5859418578171399
# Episode 267, Reward: 197, Epsilon: 0.5847699741015057
# Episode 268, Reward: 79, Epsilon: 0.5836004341533026
# Episode 269, Reward: -371, Epsilon: 0.5824332332849961
# Episode 270, Reward: -981, Epsilon: 0.5812683668184261
# Episode 271, Reward: -176, Epsilon: 0.5801058300847892
# Episode 272, Reward: -150, Epsilon: 0.5789456184246197
# Episode 273, Reward: -150, Epsilon: 0.5777877271877704
# Episode 274, Reward: 220, Epsilon: 0.5766321517333949
# Episode 275, Reward: -150, Epsilon: 0.5754788874299281
# Episode 276, Reward: -1106, Epsilon: 0.5743279296550683
# Episode 277, Reward: 229, Epsilon: 0.5731792737957582
# Episode 278, Reward: -16, Epsilon: 0.5720329152481667
# Episode 279, Reward: 265, Epsilon: 0.5708888494176704
# Episode 280, Reward: 89, Epsilon: 0.569747071718835
# Episode 281, Reward: -475, Epsilon: 0.5686075775753973
# Episode 282, Reward: -75, Epsilon: 0.5674703624202465
# Episode 283, Reward: -1725, Epsilon: 0.5663354216954061
# Episode 284, Reward: -101, Epsilon: 0.5652027508520152
# Episode 285, Reward: -475, Epsilon: 0.5640723453503111
# Episode 286, Reward: 297, Epsilon: 0.5629442006596105
# Episode 287, Reward: 45, Epsilon: 0.5618183122582913
# Episode 288, Reward: -6, Epsilon: 0.5606946756337747
# Episode 289, Reward: 59, Epsilon: 0.5595732862825071
# Episode 290, Reward: -191, Epsilon: 0.5584541397099421
# Episode 291, Reward: -105, Epsilon: 0.5573372314305222
# Episode 292, Reward: -945, Epsilon: 0.5562225569676611
# Episode 293, Reward: -1978, Epsilon: 0.5551101118537257
# Episode 294, Reward: -350, Epsilon: 0.5539998916300183
# Episode 295, Reward: 234, Epsilon: 0.5528918918467582
# Episode 296, Reward: -1100, Epsilon: 0.5517861080630647
# Episode 297, Reward: 222, Epsilon: 0.5506825358469386
# Episode 298, Reward: 214, Epsilon: 0.5495811707752447
# Episode 299, Reward: 322, Epsilon: 0.5484820084336942
# Episode 300, Reward: 230, Epsilon: 0.5473850444168268
# Episode 301, Reward: 254, Epsilon: 0.5462902743279932
# Episode 302, Reward: 272, Epsilon: 0.5451976937793371
# Episode 303, Reward: 272, Epsilon: 0.5441072983917784
# Episode 304, Reward: 255, Epsilon: 0.5430190837949949
# Episode 305, Reward: -78, Epsilon: 0.5419330456274049
# Episode 306, Reward: 179, Epsilon: 0.5408491795361501
# Episode 307, Reward: -125, Epsilon: 0.5397674811770777
# Episode 308, Reward: 170, Epsilon: 0.5386879462147236
# Episode 309, Reward: -75, Epsilon: 0.5376105703222942
# Episode 310, Reward: -605, Epsilon: 0.5365353491816496
# Episode 311, Reward: 172, Epsilon: 0.5354622784832863
# Episode 312, Reward: -470, Epsilon: 0.5343913539263198
# Episode 313, Reward: -425, Epsilon: 0.5333225712184672
# Episode 314, Reward: -300, Epsilon: 0.5322559260760302
# Episode 315, Reward: -975, Epsilon: 0.5311914142238782
# Episode 316, Reward: -1250, Epsilon: 0.5301290313954304
# Episode 317, Reward: -1250, Epsilon: 0.5290687733326396
# Episode 318, Reward: 139, Epsilon: 0.5280106357859743
# Episode 319, Reward: 214, Epsilon: 0.5269546145144024
# Episode 320, Reward: 349, Epsilon: 0.5259007052853736
# Episode 321, Reward: 160, Epsilon: 0.5248489038748029
# Episode 322, Reward: -403, Epsilon: 0.5237992060670532
# Episode 323, Reward: -1950, Epsilon: 0.5227516076549191
# Episode 324, Reward: 305, Epsilon: 0.5217061044396093
# Episode 325, Reward: 255, Epsilon: 0.52066269223073
# Episode 326, Reward: -211, Epsilon: 0.5196213668462686
# Episode 327, Reward: 264, Epsilon: 0.5185821241125761
# Episode 328, Reward: 222, Epsilon: 0.5175449598643509
# Episode 329, Reward: 147, Epsilon: 0.5165098699446222
# Episode 330, Reward: -685, Epsilon: 0.515476850204733
# Episode 331, Reward: 215, Epsilon: 0.5144458965043235
# Episode 332, Reward: 230, Epsilon: 0.5134170047113148
# Episode 333, Reward: 214, Epsilon: 0.5123901707018922
# Episode 334, Reward: 284, Epsilon: 0.5113653903604884
# Episode 335, Reward: -436, Epsilon: 0.5103426595797674
# Episode 336, Reward: 314, Epsilon: 0.5093219742606079
# Episode 337, Reward: 265, Epsilon: 0.5083033303120866
# Episode 338, Reward: 79, Epsilon: 0.5072867236514624
# Episode 339, Reward: 165, Epsilon: 0.5062721502041595
# Episode 340, Reward: -470, Epsilon: 0.5052596059037512
# Episode 341, Reward: -50, Epsilon: 0.5042490866919437
# Episode 342, Reward: 249, Epsilon: 0.5032405885185598
# Episode 343, Reward: 275, Epsilon: 0.5022341073415226
# Episode 344, Reward: -65, Epsilon: 0.5012296391268396
# Episode 345, Reward: 295, Epsilon: 0.5002271798485859
# Episode 346, Reward: -260, Epsilon: 0.4992267254888887
# Episode 347, Reward: 259, Epsilon: 0.4982282720379109
# Episode 348, Reward: 245, Epsilon: 0.4972318154938351
# Episode 349, Reward: 115, Epsilon: 0.49623735186284745
# Episode 350, Reward: 264, Epsilon: 0.49524487715912174
# Episode 351, Reward: 335, Epsilon: 0.4942543874048035
# Episode 352, Reward: 335, Epsilon: 0.4932658786299939
# Episode 353, Reward: 209, Epsilon: 0.4922793468727339
# Episode 354, Reward: 259, Epsilon: 0.4912947881789884
# Episode 355, Reward: 180, Epsilon: 0.4903121986026304
# Episode 356, Reward: 284, Epsilon: 0.48933157420542517
# Episode 357, Reward: 284, Epsilon: 0.48835291105701434
# Episode 358, Reward: -746, Epsilon: 0.48737620523490033
# Episode 359, Reward: -120, Epsilon: 0.48640145282443054
# Episode 360, Reward: 195, Epsilon: 0.48542864991878165
# Episode 361, Reward: 305, Epsilon: 0.48445779261894406
# Episode 362, Reward: 272, Epsilon: 0.4834888770337062
# Episode 363, Reward: 329, Epsilon: 0.4825218992796388
# Episode 364, Reward: 245, Epsilon: 0.4815568554810795
# Episode 365, Reward: 197, Epsilon: 0.4805937417701174
# Episode 366, Reward: 245, Epsilon: 0.47963255428657714
# Episode 367, Reward: 335, Epsilon: 0.478673289178004
# Episode 368, Reward: 239, Epsilon: 0.477715942599648
# Episode 369, Reward: 272, Epsilon: 0.4767605107144487
# Episode 370, Reward: -106, Epsilon: 0.4758069896930198
# Episode 371, Reward: 189, Epsilon: 0.4748553757136338
# Episode 372, Reward: 140, Epsilon: 0.47390566496220654
# Episode 373, Reward: 275, Epsilon: 0.47295785363228215
# Episode 374, Reward: 255, Epsilon: 0.4720119379250176
# Episode 375, Reward: 200, Epsilon: 0.4710679140491676
# Episode 376, Reward: 319, Epsilon: 0.47012577822106927
# Episode 377, Reward: -150, Epsilon: 0.46918552666462715
# Episode 378, Reward: -225, Epsilon: 0.46824715561129787
# Episode 379, Reward: -601, Epsilon: 0.46731066130007526
# Episode 380, Reward: 72, Epsilon: 0.4663760399774751
# Episode 381, Reward: -1900, Epsilon: 0.46544328789752015
# Episode 382, Reward: 314, Epsilon: 0.4645124013217251
# Episode 383, Reward: 230, Epsilon: 0.46358337651908166
# Episode 384, Reward: -700, Epsilon: 0.4626562097660435
# Episode 385, Reward: -203, Epsilon: 0.4617308973465114
# Episode 386, Reward: 259, Epsilon: 0.46080743555181836
# Episode 387, Reward: -151, Epsilon: 0.4598858206807147
# Episode 388, Reward: 315, Epsilon: 0.4589660490393533
# Episode 389, Reward: 350, Epsilon: 0.45804811694127456
# Episode 390, Reward: 222, Epsilon: 0.457132020707392
# Episode 391, Reward: 172, Epsilon: 0.45621775666597725
# Episode 392, Reward: 350, Epsilon: 0.45530532115264527
# Episode 393, Reward: 284, Epsilon: 0.45439471051033997
# Episode 394, Reward: 180, Epsilon: 0.4534859210893193
# Episode 395, Reward: 340, Epsilon: 0.45257894924714065
# Episode 396, Reward: 205, Epsilon: 0.4516737913486464
# Episode 397, Reward: -303, Epsilon: 0.4507704437659491
# Episode 398, Reward: -78, Epsilon: 0.4498689028784172
# Episode 399, Reward: -375, Epsilon: 0.4489691650726603
# Episode 400, Reward: 314, Epsilon: 0.448071226742515
# Episode 401, Reward: 319, Epsilon: 0.44717508428902997
# Episode 402, Reward: 214, Epsilon: 0.4462807341204519
# Episode 403, Reward: -103, Epsilon: 0.445388172652211
# Episode 404, Reward: -300, Epsilon: 0.44449739630690654
# Episode 405, Reward: 297, Epsilon: 0.4436084015142927
# Episode 406, Reward: 234, Epsilon: 0.4427211847112641
# Episode 407, Reward: 272, Epsilon: 0.4418357423418416
# Episode 408, Reward: 259, Epsilon: 0.44095207085715793
# Episode 409, Reward: 240, Epsilon: 0.44007016671544363
# Episode 410, Reward: 297, Epsilon: 0.43919002638201277
# Episode 411, Reward: 219, Epsilon: 0.43831164632924874
# Episode 412, Reward: -31, Epsilon: 0.43743502303659026
# Episode 413, Reward: 34, Epsilon: 0.4365601529905171
# Episode 414, Reward: 230, Epsilon: 0.43568703268453607
# Episode 415, Reward: 335, Epsilon: 0.434815658619167
# Episode 416, Reward: 344, Epsilon: 0.43394602730192866
# Episode 417, Reward: -578, Epsilon: 0.4330781352473248
# Episode 418, Reward: 260, Epsilon: 0.43221197897683017
# Episode 419, Reward: 285, Epsilon: 0.4313475550188765
# Episode 420, Reward: 247, Epsilon: 0.4304848599088387
# Episode 421, Reward: -1728, Epsilon: 0.42962389018902103
# Episode 422, Reward: 245, Epsilon: 0.428764642408643
# Episode 423, Reward: 310, Epsilon: 0.4279071131238257
# Episode 424, Reward: 335, Epsilon: 0.42705129889757804
# Episode 425, Reward: 314, Epsilon: 0.42619719629978287
# Episode 426, Reward: -900, Epsilon: 0.4253448019071833
# Episode 427, Reward: -1001, Epsilon: 0.424494112303369
# Episode 428, Reward: 325, Epsilon: 0.42364512407876226
# Episode 429, Reward: -28, Epsilon: 0.4227978338306047
# Episode 430, Reward: -151, Epsilon: 0.42195223816294347
# Episode 431, Reward: 249, Epsilon: 0.4211083336866176
# Episode 432, Reward: -2030, Epsilon: 0.4202661170192444
# Episode 433, Reward: 284, Epsilon: 0.41942558478520586
# Episode 434, Reward: -85, Epsilon: 0.4185867336156355
# Episode 435, Reward: 325, Epsilon: 0.4177495601484042
# Episode 436, Reward: 34, Epsilon: 0.4169140610281074
# Episode 437, Reward: 349, Epsilon: 0.4160802329060512
# Episode 438, Reward: 144, Epsilon: 0.4152480724402391
# Episode 439, Reward: 259, Epsilon: 0.41441757629535864
# Episode 440, Reward: 310, Epsilon: 0.4135887411427679
# Episode 441, Reward: 5, Epsilon: 0.41276156366048233
# Episode 442, Reward: 272, Epsilon: 0.41193604053316135
# Episode 443, Reward: 322, Epsilon: 0.41111216845209503
# Episode 444, Reward: 314, Epsilon: 0.4102899441151908
# Episode 445, Reward: 314, Epsilon: 0.40946936422696045
# Episode 446, Reward: 247, Epsilon: 0.40865042549850655
# Episode 447, Reward: 22, Epsilon: 0.40783312464750954
# Episode 448, Reward: -1250, Epsilon: 0.4070174583982145
# Episode 449, Reward: 215, Epsilon: 0.4062034234814181
# Episode 450, Reward: 245, Epsilon: 0.40539101663445526
# Episode 451, Reward: 329, Epsilon: 0.40458023460118636
# Episode 452, Reward: 322, Epsilon: 0.403771074131984
# Episode 453, Reward: 295, Epsilon: 0.40296353198372004
# Episode 454, Reward: -175, Epsilon: 0.4021576049197526
# Episode 455, Reward: 285, Epsilon: 0.40135328970991313
# Episode 456, Reward: 272, Epsilon: 0.4005505831304933
# Episode 457, Reward: 297, Epsilon: 0.3997494819642323
# Episode 458, Reward: 264, Epsilon: 0.3989499830003039
# Episode 459, Reward: 254, Epsilon: 0.3981520830343033
# Episode 460, Reward: 245, Epsilon: 0.39735577886823464
# Episode 461, Reward: 272, Epsilon: 0.39656106731049817
# Episode 462, Reward: 319, Epsilon: 0.39576794517587716
# Episode 463, Reward: 322, Epsilon: 0.3949764092855254
# Episode 464, Reward: 297, Epsilon: 0.3941864564669544
# Episode 465, Reward: -140, Epsilon: 0.39339808355402045
# Episode 466, Reward: 179, Epsilon: 0.3926112873869124
# Episode 467, Reward: 272, Epsilon: 0.3918260648121386
# Episode 468, Reward: 329, Epsilon: 0.39104241268251433
# Episode 469, Reward: 319, Epsilon: 0.3902603278571493
# Episode 470, Reward: 179, Epsilon: 0.389479807201435
# Episode 471, Reward: 350, Epsilon: 0.3887008475870321
# Episode 472, Reward: -226, Epsilon: 0.38792344589185807
# Episode 473, Reward: 314, Epsilon: 0.38714759900007434
# Episode 474, Reward: 284, Epsilon: 0.3863733038020742
# Episode 475, Reward: 234, Epsilon: 0.38560055719447006
# Episode 476, Reward: -150, Epsilon: 0.3848293560800811
# Episode 477, Reward: -125, Epsilon: 0.38405969736792095
# Episode 478, Reward: -65, Epsilon: 0.3832915779731851
# Episode 479, Reward: 222, Epsilon: 0.38252499481723873
# Episode 480, Reward: 295, Epsilon: 0.3817599448276042
# Episode 481, Reward: 272, Epsilon: 0.380996424937949
# Episode 482, Reward: 300, Epsilon: 0.3802344320880731
# Episode 483, Reward: 245, Epsilon: 0.379473963223897
# Episode 484, Reward: 245, Epsilon: 0.37871501529744916
# Episode 485, Reward: 275, Epsilon: 0.37795758526685425
# Episode 486, Reward: -6725, Epsilon: 0.37720167009632055
# Episode 487, Reward: 249, Epsilon: 0.3764472667561279
# Episode 488, Reward: -505, Epsilon: 0.37569437222261565
# Episode 489, Reward: -470, Epsilon: 0.3749429834781704
# Episode 490, Reward: -731, Epsilon: 0.37419309751121405
# Episode 491, Reward: 125, Epsilon: 0.3734447113161916
# Episode 492, Reward: 272, Epsilon: 0.3726978218935592
# Episode 493, Reward: -1050, Epsilon: 0.3719524262497721
# Episode 494, Reward: -425, Epsilon: 0.37120852139727256
# Episode 495, Reward: 295, Epsilon: 0.370466104354478
# Episode 496, Reward: -310, Epsilon: 0.36972517214576905
# Episode 497, Reward: -100, Epsilon: 0.36898572180147754
# Episode 498, Reward: 347, Epsilon: 0.3682477503578746
# Episode 499, Reward: 322, Epsilon: 0.36751125485715885
# Episode 500, Reward: -28, Epsilon: 0.36677623234744455
# Episode 501, Reward: 234, Epsilon: 0.3660426798827497
# Episode 502, Reward: 305, Epsilon: 0.3653105945229842
# Episode 503, Reward: 179, Epsilon: 0.3645799733339382
# Episode 504, Reward: 254, Epsilon: 0.3638508133872703
# Episode 505, Reward: 324, Epsilon: 0.3631231117604958
# Episode 506, Reward: -51, Epsilon: 0.3623968655369748
# Episode 507, Reward: 335, Epsilon: 0.3616720718059009
# Episode 508, Reward: -275, Epsilon: 0.3609487276622891
# Episode 509, Reward: 245, Epsilon: 0.3602268302069645
# Episode 510, Reward: -1200, Epsilon: 0.35950637654655054
# Episode 511, Reward: -125, Epsilon: 0.35878736379345744
# Episode 512, Reward: 347, Epsilon: 0.3580697890658705
# Episode 513, Reward: 272, Epsilon: 0.35735364948773873
# Episode 514, Reward: -303, Epsilon: 0.35663894218876324
# Episode 515, Reward: -103, Epsilon: 0.3559256643043857
# Episode 516, Reward: 259, Epsilon: 0.3552138129757769
# Episode 517, Reward: -75, Epsilon: 0.35450338534982534
# Episode 518, Reward: -100, Epsilon: 0.3537943785791257
# Episode 519, Reward: -1850, Epsilon: 0.35308678982196745
# Episode 520, Reward: 340, Epsilon: 0.35238061624232353
# Episode 521, Reward: 344, Epsilon: 0.3516758550098389
# Episode 522, Reward: 195, Epsilon: 0.3509725032998192
# Episode 523, Reward: 300, Epsilon: 0.35027055829321957
# Episode 524, Reward: 340, Epsilon: 0.3495700171766331
# Episode 525, Reward: 295, Epsilon: 0.3488708771422798
# Episode 526, Reward: -75, Epsilon: 0.34817313538799527
# Episode 527, Reward: 54, Epsilon: 0.3474767891172193
# Episode 528, Reward: -75, Epsilon: 0.34678183553898484
# Episode 529, Reward: 325, Epsilon: 0.34608827186790686
# Episode 530, Reward: 279, Epsilon: 0.34539609532417104
# Episode 531, Reward: 324, Epsilon: 0.3447053031335227
# Episode 532, Reward: 74, Epsilon: 0.3440158925272557
# Episode 533, Reward: 340, Epsilon: 0.3433278607422012
# Episode 534, Reward: -875, Epsilon: 0.34264120502071677
# Episode 535, Reward: -1250, Epsilon: 0.3419559226106753
# Episode 536, Reward: -75, Epsilon: 0.34127201076545394
# Episode 537, Reward: 272, Epsilon: 0.34058946674392304
# Episode 538, Reward: 47, Epsilon: 0.3399082878104352
# Episode 539, Reward: -28, Epsilon: 0.3392284712348143
# Episode 540, Reward: 300, Epsilon: 0.33855001429234466
# Episode 541, Reward: 322, Epsilon: 0.33787291426376
# Episode 542, Reward: 154, Epsilon: 0.33719716843523245
# Episode 543, Reward: 272, Epsilon: 0.336522774098362
# Episode 544, Reward: -225, Epsilon: 0.33584972855016526
# Episode 545, Reward: 350, Epsilon: 0.33517802909306493
# Episode 546, Reward: 272, Epsilon: 0.3345076730348788
# Episode 547, Reward: 244, Epsilon: 0.33383865768880905
# Episode 548, Reward: 344, Epsilon: 0.3331709803734314
# Episode 549, Reward: 5, Epsilon: 0.3325046384126845
# Episode 550, Reward: 272, Epsilon: 0.3318396291358591
# Episode 551, Reward: 272, Epsilon: 0.3311759498775874
# Episode 552, Reward: 340, Epsilon: 0.33051359797783225
# Episode 553, Reward: 49, Epsilon: 0.3298525707818766
# Episode 554, Reward: 234, Epsilon: 0.3291928656403128
# Episode 555, Reward: -65, Epsilon: 0.3285344799090322
# Episode 556, Reward: 34, Epsilon: 0.32787741094921413
# Episode 557, Reward: 272, Epsilon: 0.3272216561273157
# Episode 558, Reward: 272, Epsilon: 0.32656721281506107
# Episode 559, Reward: 325, Epsilon: 0.32591407838943093
# Episode 560, Reward: 190, Epsilon: 0.32526225023265204
# Episode 561, Reward: 272, Epsilon: 0.3246117257321867
# Episode 562, Reward: 245, Epsilon: 0.3239625022807223
# Episode 563, Reward: 305, Epsilon: 0.32331457727616086
# Episode 564, Reward: 305, Epsilon: 0.32266794812160854
# Episode 565, Reward: 314, Epsilon: 0.3220226122253653
# Episode 566, Reward: 247, Epsilon: 0.3213785670009146
# Episode 567, Reward: 90, Epsilon: 0.3207358098669128
# Episode 568, Reward: 234, Epsilon: 0.320094338247179
# Episode 569, Reward: 220, Epsilon: 0.31945414957068463
# Episode 570, Reward: 230, Epsilon: 0.31881524127154326
# Episode 571, Reward: 272, Epsilon: 0.3181776107890002
# Episode 572, Reward: 179, Epsilon: 0.3175412555674222
# Episode 573, Reward: 280, Epsilon: 0.3169061730562873
# Episode 574, Reward: 222, Epsilon: 0.3162723607101747
# Episode 575, Reward: 314, Epsilon: 0.3156398159887544
# Episode 576, Reward: 60, Epsilon: 0.3150085363567769
# Episode 577, Reward: 272, Epsilon: 0.31437851928406335
# Episode 578, Reward: 222, Epsilon: 0.3137497622454952
# Episode 579, Reward: 245, Epsilon: 0.31312226272100424
# Episode 580, Reward: 280, Epsilon: 0.3124960181955622
# Episode 581, Reward: 299, Epsilon: 0.3118710261591711
# Episode 582, Reward: 304, Epsilon: 0.31124728410685276
# Episode 583, Reward: 230, Epsilon: 0.31062478953863903
# Episode 584, Reward: 314, Epsilon: 0.31000353995956176
# Episode 585, Reward: 34, Epsilon: 0.30938353287964265
# Episode 586, Reward: 222, Epsilon: 0.30876476581388335
# Episode 587, Reward: -75, Epsilon: 0.3081472362822556
# Episode 588, Reward: -200, Epsilon: 0.3075309418096911
# Episode 589, Reward: 329, Epsilon: 0.3069158799260717
# Episode 590, Reward: 159, Epsilon: 0.3063020481662196
# Episode 591, Reward: 280, Epsilon: 0.30568944406988713
# Episode 592, Reward: -865, Epsilon: 0.30507806518174735
# Episode 593, Reward: 260, Epsilon: 0.3044679090513839
# Episode 594, Reward: -303, Epsilon: 0.3038589732332811
# Episode 595, Reward: 295, Epsilon: 0.3032512552868145
# Episode 596, Reward: 255, Epsilon: 0.30264475277624087
# Episode 597, Reward: 270, Epsilon: 0.30203946327068837
# Episode 598, Reward: -210, Epsilon: 0.301435384344147
# Episode 599, Reward: 240, Epsilon: 0.3008325135754587
# Episode 600, Reward: 329, Epsilon: 0.3002308485483078
# Episode 601, Reward: 147, Epsilon: 0.2996303868512112
# Episode 602, Reward: -2100, Epsilon: 0.29903112607750876
# Episode 603, Reward: 190, Epsilon: 0.29843306382535373
# Episode 604, Reward: 329, Epsilon: 0.29783619769770303
# Episode 605, Reward: 322, Epsilon: 0.2972405253023076
# Episode 606, Reward: 259, Epsilon: 0.296646044251703
# Episode 607, Reward: -11, Epsilon: 0.2960527521631996
# Episode 608, Reward: 280, Epsilon: 0.29546064665887317
# Episode 609, Reward: 279, Epsilon: 0.29486972536555545
# Episode 610, Reward: 349, Epsilon: 0.29427998591482435
# Episode 611, Reward: 297, Epsilon: 0.2936914259429947
# Episode 612, Reward: 184, Epsilon: 0.2931040430911087
# Episode 613, Reward: 272, Epsilon: 0.2925178350049265
# Episode 614, Reward: 272, Epsilon: 0.29193279933491667
# Episode 615, Reward: 189, Epsilon: 0.2913489337362468
# Episode 616, Reward: 304, Epsilon: 0.2907662358687743
# Episode 617, Reward: -253, Epsilon: 0.2901847033970368
# Episode 618, Reward: -75, Epsilon: 0.2896043339902427
# Episode 619, Reward: 247, Epsilon: 0.2890251253222622
# Episode 620, Reward: 272, Epsilon: 0.2884470750716177
# Episode 621, Reward: 272, Epsilon: 0.2878701809214745
# Episode 622, Reward: -28, Epsilon: 0.28729444055963155
# Episode 623, Reward: -75, Epsilon: 0.28671985167851227
# Episode 624, Reward: 329, Epsilon: 0.2861464119751552
# Episode 625, Reward: 297, Epsilon: 0.2855741191512049
# Episode 626, Reward: -100, Epsilon: 0.2850029709129025
# Episode 627, Reward: -100, Epsilon: 0.2844329649710767
# Episode 628, Reward: -75, Epsilon: 0.2838640990411345
# Episode 629, Reward: 270, Epsilon: 0.28329637084305226
# Episode 630, Reward: -100, Epsilon: 0.2827297781013662
# Episode 631, Reward: 340, Epsilon: 0.28216431854516344
# Episode 632, Reward: 264, Epsilon: 0.2815999899080731
# Episode 633, Reward: 314, Epsilon: 0.281036789928257
# Episode 634, Reward: 84, Epsilon: 0.2804747163484005
# Episode 635, Reward: 324, Epsilon: 0.2799137669157037
# Episode 636, Reward: 344, Epsilon: 0.2793539393818723
# Episode 637, Reward: 295, Epsilon: 0.2787952315031086
# Episode 638, Reward: 247, Epsilon: 0.27823764104010235
# Episode 639, Reward: 272, Epsilon: 0.27768116575802215
# Episode 640, Reward: 249, Epsilon: 0.2771258034265061
# Episode 641, Reward: 264, Epsilon: 0.2765715518196531
# Episode 642, Reward: 47, Epsilon: 0.2760184087160138
# Episode 643, Reward: 230, Epsilon: 0.27546637189858175
# Episode 644, Reward: 329, Epsilon: 0.2749154391547846
# Episode 645, Reward: 4, Epsilon: 0.27436560827647505
# Episode 646, Reward: 279, Epsilon: 0.2738168770599221
# Episode 647, Reward: 247, Epsilon: 0.2732692433058022
# Episode 648, Reward: 245, Epsilon: 0.2727227048191906
# Episode 649, Reward: 255, Epsilon: 0.27217725940955223
# Episode 650, Reward: 329, Epsilon: 0.2716329048907331
# Episode 651, Reward: 272, Epsilon: 0.2710896390809516
# Episode 652, Reward: 272, Epsilon: 0.2705474598027897
# Episode 653, Reward: -866, Epsilon: 0.27000636488318414
# Episode 654, Reward: 5, Epsilon: 0.26946635215341774
# Episode 655, Reward: 140, Epsilon: 0.2689274194491109
# Episode 656, Reward: 300, Epsilon: 0.2683895646102127
# Episode 657, Reward: -28, Epsilon: 0.2678527854809923
# Episode 658, Reward: 279, Epsilon: 0.2673170799100303
# Episode 659, Reward: 290, Epsilon: 0.2667824457502102
# Episode 660, Reward: 20, Epsilon: 0.2662488808587098
# Episode 661, Reward: 324, Epsilon: 0.26571638309699236
# Episode 662, Reward: 245, Epsilon: 0.26518495033079836
# Episode 663, Reward: 314, Epsilon: 0.2646545804301368
# Episode 664, Reward: -1651, Epsilon: 0.26412527126927654
# Episode 665, Reward: 284, Epsilon: 0.26359702072673796
# Episode 666, Reward: 259, Epsilon: 0.2630698266852845
# Episode 667, Reward: 259, Epsilon: 0.26254368703191394
# Episode 668, Reward: 245, Epsilon: 0.2620185996578501
# Episode 669, Reward: 245, Epsilon: 0.2614945624585344
# Episode 670, Reward: 349, Epsilon: 0.26097157333361737
# Episode 671, Reward: 245, Epsilon: 0.2604496301869501
# Episode 672, Reward: -2026, Epsilon: 0.2599287309265762
# Episode 673, Reward: -2300, Epsilon: 0.259408873464723
# Episode 674, Reward: 272, Epsilon: 0.25889005571779355
# Episode 675, Reward: 347, Epsilon: 0.25837227560635795
# Episode 676, Reward: -1025, Epsilon: 0.25785553105514525
# Episode 677, Reward: 185, Epsilon: 0.25733981999303496
# Episode 678, Reward: -420, Epsilon: 0.2568251403530489
# Episode 679, Reward: 75, Epsilon: 0.2563114900723428
# Episode 680, Reward: -28, Epsilon: 0.25579886709219807
# Episode 681, Reward: -100, Epsilon: 0.25528726935801366
# Episode 682, Reward: 305, Epsilon: 0.25477669481929766
# Episode 683, Reward: 322, Epsilon: 0.25426714142965906
# Episode 684, Reward: -75, Epsilon: 0.25375860714679976
# Episode 685, Reward: 214, Epsilon: 0.25325108993250617
# Episode 686, Reward: 272, Epsilon: 0.25274458775264114
# Episode 687, Reward: -2675, Epsilon: 0.25223909857713583
# Episode 688, Reward: 272, Epsilon: 0.25173462037998157
# Episode 689, Reward: 5, Epsilon: 0.2512311511392216
# Episode 690, Reward: 272, Epsilon: 0.25072868883694316
# Episode 691, Reward: 245, Epsilon: 0.2502272314592693
# Episode 692, Reward: -230, Epsilon: 0.24972677699635074
# Episode 693, Reward: 245, Epsilon: 0.24922732344235804
# Episode 694, Reward: 239, Epsilon: 0.24872886879547332
# Episode 695, Reward: 245, Epsilon: 0.24823141105788238
# Episode 696, Reward: 264, Epsilon: 0.2477349482357666
# Episode 697, Reward: -181, Epsilon: 0.24723947833929508
# Episode 698, Reward: 295, Epsilon: 0.2467449993826165
# Episode 699, Reward: 344, Epsilon: 0.24625150938385126
# Episode 700, Reward: 272, Epsilon: 0.24575900636508355
# Episode 701, Reward: 284, Epsilon: 0.24526748835235337
# Episode 702, Reward: 245, Epsilon: 0.24477695337564867
# Episode 703, Reward: 259, Epsilon: 0.24428739946889738
# Episode 704, Reward: 199, Epsilon: 0.24379882466995959
# Episode 705, Reward: 297, Epsilon: 0.24331122702061966
# Episode 706, Reward: 209, Epsilon: 0.24282460456657842
# Episode 707, Reward: 255, Epsilon: 0.24233895535744526
# Episode 708, Reward: 340, Epsilon: 0.24185427744673038
# Episode 709, Reward: 255, Epsilon: 0.24137056889183692
# Episode 710, Reward: 295, Epsilon: 0.24088782775405324
# Episode 711, Reward: -203, Epsilon: 0.24040605209854513
# Episode 712, Reward: 305, Epsilon: 0.23992523999434803
# Episode 713, Reward: 259, Epsilon: 0.23944538951435934
# Episode 714, Reward: 245, Epsilon: 0.23896649873533063
# Episode 715, Reward: -425, Epsilon: 0.23848856573785998
# Episode 716, Reward: 245, Epsilon: 0.23801158860638427
# Episode 717, Reward: 245, Epsilon: 0.2375355654291715
# Episode 718, Reward: 245, Epsilon: 0.23706049429831316
# Episode 719, Reward: 272, Epsilon: 0.23658637330971655
# Episode 720, Reward: 244, Epsilon: 0.23611320056309712
# Episode 721, Reward: 245, Epsilon: 0.2356409741619709
# Episode 722, Reward: 322, Epsilon: 0.23516969221364697
# Episode 723, Reward: 305, Epsilon: 0.2346993528292197
# Episode 724, Reward: -75, Epsilon: 0.23422995412356126
# Episode 725, Reward: 280, Epsilon: 0.23376149421531414
# Episode 726, Reward: 234, Epsilon: 0.2332939712268835
# Episode 727, Reward: 272, Epsilon: 0.23282738328442973
# Episode 728, Reward: -175, Epsilon: 0.23236172851786085
# Episode 729, Reward: 284, Epsilon: 0.23189700506082514
# Episode 730, Reward: 214, Epsilon: 0.2314332110507035
# Episode 731, Reward: 305, Epsilon: 0.23097034462860208
# Episode 732, Reward: 295, Epsilon: 0.23050840393934488
# Episode 733, Reward: 280, Epsilon: 0.2300473871314662
# Episode 734, Reward: 230, Epsilon: 0.22958729235720327
# Episode 735, Reward: 5, Epsilon: 0.22912811777248887
# Episode 736, Reward: 295, Epsilon: 0.22866986153694388
# Episode 737, Reward: 329, Epsilon: 0.22821252181387
# Episode 738, Reward: 284, Epsilon: 0.22775609677024225
# Episode 739, Reward: 295, Epsilon: 0.22730058457670177
# Episode 740, Reward: 272, Epsilon: 0.22684598340754836
# Episode 741, Reward: 245, Epsilon: 0.22639229144073325
# Episode 742, Reward: 340, Epsilon: 0.22593950685785177
# Episode 743, Reward: 245, Epsilon: 0.22548762784413606
# Episode 744, Reward: 272, Epsilon: 0.2250366525884478
# Episode 745, Reward: 209, Epsilon: 0.2245865792832709
# Episode 746, Reward: 329, Epsilon: 0.22413740612470434
# Episode 747, Reward: 245, Epsilon: 0.22368913131245494
# Episode 748, Reward: 245, Epsilon: 0.22324175304983002
# Episode 749, Reward: 245, Epsilon: 0.22279526954373036
# Episode 750, Reward: 322, Epsilon: 0.2223496790046429
# Episode 751, Reward: 270, Epsilon: 0.2219049796466336
# Episode 752, Reward: -75, Epsilon: 0.22146116968734034
# Episode 753, Reward: 214, Epsilon: 0.22101824734796566
# Episode 754, Reward: -75, Epsilon: 0.22057621085326973
# Episode 755, Reward: -75, Epsilon: 0.2201350584315632
# Episode 756, Reward: 314, Epsilon: 0.21969478831470007
# Episode 757, Reward: 34, Epsilon: 0.21925539873807068
# Episode 758, Reward: 295, Epsilon: 0.21881688794059453
# Episode 759, Reward: 295, Epsilon: 0.21837925416471335
# Episode 760, Reward: 84, Epsilon: 0.21794249565638393
# Episode 761, Reward: 329, Epsilon: 0.21750661066507115
# Episode 762, Reward: 264, Epsilon: 0.21707159744374102
# Episode 763, Reward: 279, Epsilon: 0.21663745424885353
# Episode 764, Reward: 230, Epsilon: 0.21620417934035582
# Episode 765, Reward: 322, Epsilon: 0.2157717709816751
# Episode 766, Reward: 295, Epsilon: 0.21534022743971176
# Episode 767, Reward: -75, Epsilon: 0.21490954698483233
# Episode 768, Reward: -125, Epsilon: 0.21447972789086267
# Episode 769, Reward: 69, Epsilon: 0.21405076843508095
# Episode 770, Reward: -225, Epsilon: 0.21362266689821077
# Episode 771, Reward: -741, Epsilon: 0.21319542156441434
# Episode 772, Reward: 335, Epsilon: 0.21276903072128553
# Episode 773, Reward: 225, Epsilon: 0.21234349265984295
# Episode 774, Reward: 234, Epsilon: 0.21191880567452326
# Episode 775, Reward: 329, Epsilon: 0.21149496806317422
# Episode 776, Reward: 214, Epsilon: 0.21107197812704787
# Episode 777, Reward: 247, Epsilon: 0.21064983417079378
# Episode 778, Reward: 349, Epsilon: 0.21022853450245219
# Episode 779, Reward: -75, Epsilon: 0.2098080774334473
# Episode 780, Reward: 314, Epsilon: 0.20938846127858038
# Episode 781, Reward: 284, Epsilon: 0.20896968435602323
# Episode 782, Reward: 209, Epsilon: 0.2085517449873112
# Episode 783, Reward: 305, Epsilon: 0.20813464149733657
# Episode 784, Reward: 34, Epsilon: 0.2077183722143419
# Episode 785, Reward: 305, Epsilon: 0.2073029354699132
# Episode 786, Reward: 325, Epsilon: 0.20688832959897338
# Episode 787, Reward: 322, Epsilon: 0.20647455293977543
# Episode 788, Reward: 314, Epsilon: 0.20606160383389588
# Episode 789, Reward: -128, Epsilon: 0.2056494806262281
# Episode 790, Reward: 20, Epsilon: 0.20523818166497565
# Episode 791, Reward: 245, Epsilon: 0.2048277053016457
# Episode 792, Reward: 240, Epsilon: 0.20441804989104242
# Episode 793, Reward: 259, Epsilon: 0.20400921379126033
# Episode 794, Reward: 20, Epsilon: 0.20360119536367782
# Episode 795, Reward: 347, Epsilon: 0.20319399297295046
# Episode 796, Reward: 329, Epsilon: 0.20278760498700457
# Episode 797, Reward: 280, Epsilon: 0.20238202977703057
# Episode 798, Reward: 229, Epsilon: 0.2019772657174765
# Episode 799, Reward: 280, Epsilon: 0.20157331118604155
# Episode 800, Reward: 245, Epsilon: 0.20117016456366946
# Episode 801, Reward: 314, Epsilon: 0.20076782423454212
# Episode 802, Reward: 295, Epsilon: 0.20036628858607303
# Episode 803, Reward: -1250, Epsilon: 0.19996555600890087
# Episode 804, Reward: 34, Epsilon: 0.19956562489688306
# Episode 805, Reward: 314, Epsilon: 0.1991664936470893
# Episode 806, Reward: 245, Epsilon: 0.1987681606597951
# Episode 807, Reward: -203, Epsilon: 0.19837062433847552
# Episode 808, Reward: 284, Epsilon: 0.19797388308979857
# Episode 809, Reward: 340, Epsilon: 0.19757793532361898
# Episode 810, Reward: 340, Epsilon: 0.19718277945297175
# Episode 811, Reward: 272, Epsilon: 0.1967884138940658
# Episode 812, Reward: 272, Epsilon: 0.19639483706627767
# Episode 813, Reward: 245, Epsilon: 0.1960020473921451
# Episode 814, Reward: 247, Epsilon: 0.1956100432973608
# Episode 815, Reward: 305, Epsilon: 0.19521882321076608
# Episode 816, Reward: 347, Epsilon: 0.19482838556434456
# Episode 817, Reward: 272, Epsilon: 0.1944387287932159
# Episode 818, Reward: 272, Epsilon: 0.19404985133562946
# Episode 819, Reward: 295, Epsilon: 0.1936617516329582
# Episode 820, Reward: 245, Epsilon: 0.19327442812969228
# Episode 821, Reward: 272, Epsilon: 0.1928878792734329
# Episode 822, Reward: 34, Epsilon: 0.19250210351488603
# Episode 823, Reward: 295, Epsilon: 0.19211709930785625
# Episode 824, Reward: 314, Epsilon: 0.19173286510924054
# Episode 825, Reward: 284, Epsilon: 0.19134939937902207
# Episode 826, Reward: 295, Epsilon: 0.19096670058026402
# Episode 827, Reward: -75, Epsilon: 0.1905847671791035
# Episode 828, Reward: -400, Epsilon: 0.1902035976447453
# Episode 829, Reward: 349, Epsilon: 0.1898231904494558
# Episode 830, Reward: 347, Epsilon: 0.1894435440685569
# Episode 831, Reward: 295, Epsilon: 0.1890646569804198
# Episode 832, Reward: 350, Epsilon: 0.18868652766645896
# Episode 833, Reward: 329, Epsilon: 0.18830915461112605
# Episode 834, Reward: 347, Epsilon: 0.1879325363019038
# Episode 835, Reward: 164, Epsilon: 0.18755667122929998
# Episode 836, Reward: 272, Epsilon: 0.18718155788684138
# Episode 837, Reward: 272, Epsilon: 0.1868071947710677
# Episode 838, Reward: 329, Epsilon: 0.18643358038152555
# Episode 839, Reward: 245, Epsilon: 0.1860607132207625
# Episode 840, Reward: 314, Epsilon: 0.18568859179432098
# Episode 841, Reward: 335, Epsilon: 0.18531721461073233
# Episode 842, Reward: 147, Epsilon: 0.18494658018151086
# Episode 843, Reward: -55, Epsilon: 0.18457668702114785
# Episode 844, Reward: 247, Epsilon: 0.18420753364710554
# Episode 845, Reward: 335, Epsilon: 0.18383911857981133
# Episode 846, Reward: 347, Epsilon: 0.1834714403426517
# Episode 847, Reward: 245, Epsilon: 0.1831044974619664
# Episode 848, Reward: 314, Epsilon: 0.18273828846704246
# Episode 849, Reward: -75, Epsilon: 0.18237281189010837
# Episode 850, Reward: 344, Epsilon: 0.18200806626632815
# Episode 851, Reward: 140, Epsilon: 0.1816440501337955
# Episode 852, Reward: 59, Epsilon: 0.18128076203352791
# Episode 853, Reward: -75, Epsilon: 0.18091820050946086
# Episode 854, Reward: 305, Epsilon: 0.18055636410844195
# Episode 855, Reward: -75, Epsilon: 0.18019525138022507
# Episode 856, Reward: 5, Epsilon: 0.17983486087746461
# Episode 857, Reward: 215, Epsilon: 0.17947519115570967
# Episode 858, Reward: 294, Epsilon: 0.17911624077339824
# Episode 859, Reward: 222, Epsilon: 0.17875800829185146
# Episode 860, Reward: -281, Epsilon: 0.17840049227526775
# Episode 861, Reward: 197, Epsilon: 0.1780436912907172
# Episode 862, Reward: 295, Epsilon: 0.17768760390813576
# Episode 863, Reward: 255, Epsilon: 0.17733222870031948
# Episode 864, Reward: 295, Epsilon: 0.17697756424291883
# Episode 865, Reward: 264, Epsilon: 0.17662360911443298
# Episode 866, Reward: 347, Epsilon: 0.17627036189620413
# Episode 867, Reward: 349, Epsilon: 0.17591782117241173
# Episode 868, Reward: 272, Epsilon: 0.17556598553006691
# Episode 869, Reward: -128, Epsilon: 0.1752148535590068
# Episode 870, Reward: 272, Epsilon: 0.17486442385188877
# Episode 871, Reward: -10845, Epsilon: 0.17451469500418498
# Episode 872, Reward: -75, Epsilon: 0.17416566561417662
# Episode 873, Reward: -226, Epsilon: 0.17381733428294827
# Episode 874, Reward: 119, Epsilon: 0.17346969961438236
# Episode 875, Reward: -125, Epsilon: 0.1731227602151536
# Episode 876, Reward: -75, Epsilon: 0.1727765146947233
# Episode 877, Reward: -75, Epsilon: 0.17243096166533387
# Episode 878, Reward: -75, Epsilon: 0.1720860997420032
# Episode 879, Reward: -125, Epsilon: 0.17174192754251918
# Episode 880, Reward: -75, Epsilon: 0.17139844368743415
# Episode 881, Reward: -75, Epsilon: 0.17105564680005927
# Episode 882, Reward: -100, Epsilon: 0.17071353550645915
# Episode 883, Reward: -975, Epsilon: 0.17037210843544623
# Episode 884, Reward: -75, Epsilon: 0.17003136421857534
# Episode 885, Reward: -125, Epsilon: 0.1696913014901382
# Episode 886, Reward: -75, Epsilon: 0.16935191888715792
# Episode 887, Reward: -125, Epsilon: 0.1690132150493836
# Episode 888, Reward: -75, Epsilon: 0.16867518861928482
# Episode 889, Reward: -225, Epsilon: 0.16833783824204626
# Episode 890, Reward: -75, Epsilon: 0.16800116256556216
# Episode 891, Reward: -75, Epsilon: 0.16766516024043104
# Episode 892, Reward: -75, Epsilon: 0.16732982991995018
# Episode 893, Reward: -900, Epsilon: 0.1669951702601103
# Episode 894, Reward: -75, Epsilon: 0.16666117991959006
# Episode 895, Reward: -75, Epsilon: 0.16632785755975088
# Episode 896, Reward: -1100, Epsilon: 0.16599520184463137
# Episode 897, Reward: -125, Epsilon: 0.16566321144094212
# Episode 898, Reward: -125, Epsilon: 0.16533188501806023
# Episode 899, Reward: -75, Epsilon: 0.1650012212480241
# Episode 900, Reward: -75, Epsilon: 0.16467121880552807
# Episode 901, Reward: -100, Epsilon: 0.164341876367917
# Episode 902, Reward: -1325, Epsilon: 0.16401319261518116
# Episode 903, Reward: -125, Epsilon: 0.1636851662299508
# Episode 904, Reward: -100, Epsilon: 0.1633577958974909
# Episode 905, Reward: -75, Epsilon: 0.1630310803056959
# Episode 906, Reward: -125, Epsilon: 0.1627050181450845
# Episode 907, Reward: -1025, Epsilon: 0.16237960810879434
# Episode 908, Reward: -75, Epsilon: 0.16205484889257676
# Episode 909, Reward: -75, Epsilon: 0.1617307391947916
# Episode 910, Reward: -75, Epsilon: 0.16140727771640204
# Episode 911, Reward: -75, Epsilon: 0.16108446316096922
# Episode 912, Reward: -75, Epsilon: 0.16076229423464727
# Episode 913, Reward: -75, Epsilon: 0.16044076964617798
# Episode 914, Reward: -100, Epsilon: 0.16011988810688563
# Episode 915, Reward: -1250, Epsilon: 0.15979964833067187
# Episode 916, Reward: -150, Epsilon: 0.15948004903401053
# Episode 917, Reward: -75, Epsilon: 0.1591610889359425
# Episode 918, Reward: -75, Epsilon: 0.1588427667580706
# Episode 919, Reward: -75, Epsilon: 0.15852508122455447
# Episode 920, Reward: -75, Epsilon: 0.15820803106210535
# Episode 921, Reward: -125, Epsilon: 0.15789161499998114
# Episode 922, Reward: -75, Epsilon: 0.1575758317699812
# Episode 923, Reward: -1250, Epsilon: 0.15726068010644123
# Episode 924, Reward: -125, Epsilon: 0.15694615874622836
# Episode 925, Reward: -1325, Epsilon: 0.1566322664287359
# Episode 926, Reward: -1250, Epsilon: 0.15631900189587844
# Episode 927, Reward: -650, Epsilon: 0.1560063638920867
# Episode 928, Reward: -75, Epsilon: 0.15569435116430252
# Episode 929, Reward: -75, Epsilon: 0.15538296246197392
# Episode 930, Reward: -75, Epsilon: 0.15507219653704996
# Episode 931, Reward: 264, Epsilon: 0.15476205214397584
# Episode 932, Reward: -75, Epsilon: 0.1544525280396879
# Episode 933, Reward: 245, Epsilon: 0.1541436229836085
# Episode 934, Reward: 294, Epsilon: 0.1538353357376413
# Episode 935, Reward: -115, Epsilon: 0.15352766506616602
# Episode 936, Reward: 245, Epsilon: 0.15322060973603369
# Episode 937, Reward: -75, Epsilon: 0.15291416851656162
# Episode 938, Reward: -1250, Epsilon: 0.15260834017952848
# Episode 939, Reward: 335, Epsilon: 0.15230312349916944
# Episode 940, Reward: 259, Epsilon: 0.1519985172521711
# Episode 941, Reward: 272, Epsilon: 0.15169452021766675
# Episode 942, Reward: 245, Epsilon: 0.1513911311772314
# Episode 943, Reward: 245, Epsilon: 0.15108834891487694
# Episode 944, Reward: 245, Epsilon: 0.15078617221704718
# Episode 945, Reward: 245, Epsilon: 0.1504845998726131
# Episode 946, Reward: 314, Epsilon: 0.15018363067286786
# Episode 947, Reward: 272, Epsilon: 0.1498832634115221
# Episode 948, Reward: 84, Epsilon: 0.14958349688469907
# Episode 949, Reward: -153, Epsilon: 0.14928432989092968
# Episode 950, Reward: 272, Epsilon: 0.14898576123114782
# Episode 951, Reward: -5778, Epsilon: 0.1486877897086855
# Episode 952, Reward: -925, Epsilon: 0.14839041412926815
# Episode 953, Reward: 189, Epsilon: 0.1480936333010096
# Episode 954, Reward: -1175, Epsilon: 0.1477974460344076
# Episode 955, Reward: 214, Epsilon: 0.14750185114233877
# Episode 956, Reward: 234, Epsilon: 0.14720684744005408
# Episode 957, Reward: 222, Epsilon: 0.14691243374517396
# Episode 958, Reward: 245, Epsilon: 0.1466186088776836
# Episode 959, Reward: 272, Epsilon: 0.14632537165992823
# Episode 960, Reward: 344, Epsilon: 0.14603272091660838
# Episode 961, Reward: 245, Epsilon: 0.14574065547477516
# Episode 962, Reward: 25, Epsilon: 0.1454491741638256
# Episode 963, Reward: 245, Epsilon: 0.14515827581549795
# Episode 964, Reward: 245, Epsilon: 0.14486795926386695
# Episode 965, Reward: -250, Epsilon: 0.1445782233453392
# Episode 966, Reward: 245, Epsilon: 0.14428906689864854
# Episode 967, Reward: 55, Epsilon: 0.14400048876485125
# Episode 968, Reward: 160, Epsilon: 0.14371248778732154
# Episode 969, Reward: 209, Epsilon: 0.14342506281174688
# Episode 970, Reward: 325, Epsilon: 0.1431382126861234
# Episode 971, Reward: 314, Epsilon: 0.14285193626075116
# Episode 972, Reward: 234, Epsilon: 0.14256623238822966
# Episode 973, Reward: 272, Epsilon: 0.1422810999234532
# Episode 974, Reward: 259, Epsilon: 0.1419965377236063
# Episode 975, Reward: 350, Epsilon: 0.14171254464815908
# Episode 976, Reward: 250, Epsilon: 0.14142911955886275
# Episode 977, Reward: 295, Epsilon: 0.14114626131974503
# Episode 978, Reward: 295, Epsilon: 0.14086396879710555
# Episode 979, Reward: 245, Epsilon: 0.14058224085951135
# Episode 980, Reward: 245, Epsilon: 0.14030107637779232
# Episode 981, Reward: 189, Epsilon: 0.14002047422503675
# Episode 982, Reward: -1850, Epsilon: 0.13974043327658667
# Episode 983, Reward: 245, Epsilon: 0.1394609524100335
# Episode 984, Reward: 272, Epsilon: 0.13918203050521344
# Episode 985, Reward: 272, Epsilon: 0.13890366644420302
# Episode 986, Reward: 297, Epsilon: 0.13862585911131461
# Episode 987, Reward: 129, Epsilon: 0.138348607393092
# Episode 988, Reward: -146, Epsilon: 0.1380719101783058
# Episode 989, Reward: -75, Epsilon: 0.13779576635794918
# Episode 990, Reward: -200, Epsilon: 0.1375201748252333
# Episode 991, Reward: -75, Epsilon: 0.13724513447558281
# Episode 992, Reward: 160, Epsilon: 0.13697064420663166
# Episode 993, Reward: 272, Epsilon: 0.1366967029182184
# Episode 994, Reward: 234, Epsilon: 0.13642330951238196
# Episode 995, Reward: 195, Epsilon: 0.1361504628933572
# Episode 996, Reward: 140, Epsilon: 0.13587816196757047
# Episode 997, Reward: 245, Epsilon: 0.13560640564363532
# Episode 998, Reward: 245, Epsilon: 0.13533519283234804
# Episode 999, Reward: 222, Epsilon: 0.13506452244668335
# Training complete.
# Plot saved at: /home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/dqn_warehouse_robot_reward_per_episode.png
# Plot saved at: /home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/dqn_warehouse_robot_epsilon_decay.png

# %% [markdown]
# ### Dueling DQN, Observation Type: Vector

# %%
num_of_episodes = 1000
max_steps = 50
learning_rate = 1e-2
min_epsilon = 0.1
epsilon_decay_factor = 0.998
batch_size = 32
gamma = 0.9
C = 20

# Define your neural network architecture.
class DuelingNeuralNetwork(nn.Module):
    def __init__(self):
        super(DuelingNeuralNetwork, self).__init__()

        self.fc1 = nn.Linear(3, 64)
        self.fc2 = nn.Linear(64, 64)
        self.value_fc = nn.Linear(64, 1)
        self.advantage_fc = nn.Linear(64, 4)  

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        value = self.value_fc(x)
        advantage = self.advantage_fc(x)
        q_values = value + (advantage - advantage.mean())

        return q_values


# DQN Agent class
class DuelingDQN():
    def __init__(self, env):
        self.env = env
        self.D = deque([], maxlen=1000)  # replay memory
        self.batch_size = batch_size

        self.Q_policy = DuelingNeuralNetwork()  # main network
        self.Q_prime = DuelingNeuralNetwork()   # target network
        self.Q_prime.load_state_dict(self.Q_policy.state_dict())

        self.init_epsilon = 1.0
        self.rewards = []
        self.epsilon_arr = []
        self.total_steps = 0

        self.criterion = nn.MSELoss()
        self.optimizer = optim.AdamW(self.Q_policy.parameters(), lr=learning_rate)

    def epsilon_greedy(self, prev_state):
        if self.init_epsilon > np.random.random():
            action = self.env.action_space.sample()
        else:
            # prev_state is a 6x6 grayscale image.
            state_tensor = torch.tensor(prev_state, dtype=torch.float32).unsqueeze(0)
            # The forward pass will flatten the image.
            q_values = self.Q_policy(state_tensor)
            action = torch.argmax(q_values).item()
        return action

    def train_model(self):
        if len(self.D) < self.batch_size:
            return

        batch = random.sample(self.D, self.batch_size)

        # Convert batch elements to tensors.
        # Here, s[0] and s[3] are 6x6 images.
        states = torch.tensor([s[0] for s in batch], dtype=torch.float32)
        actions = torch.tensor([s[1] for s in batch], dtype=torch.long).unsqueeze(1)
        rewards = torch.tensor([s[2] for s in batch], dtype=torch.float32)
        next_states = torch.tensor([s[3] for s in batch], dtype=torch.float32)
        dones = torch.tensor([s[4] for s in batch], dtype=torch.float32)

        # Flatten the states to [batch_size, 36] (if not already flattened).
        states = states.view(states.size(0), -1)
        next_states = next_states.view(next_states.size(0), -1)

        # Get the predicted Q-values for the actions taken.
        current_q_values = self.Q_policy(states).gather(1, actions)

        # Compute the target Q-values using the target network.
        next_q_values = self.Q_prime(next_states).max(1)[0]
        target_q_values = rewards + (1 - dones) * gamma * next_q_values
        target_q_values = target_q_values.unsqueeze(1)

        loss = self.criterion(current_q_values, target_q_values)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        return loss.item()

    def train(self):
        for episode in range(num_of_episodes):
            prev_state, info = self.env.reset()
            ep_reward = 0

            for t in range(max_steps):
                action = self.epsilon_greedy(prev_state)
                next_state, reward, terminated, truncated, info = self.env.step(action)
                ep_reward += reward

                done = terminated  # or terminated or truncated
                self.D.append((prev_state, action, reward, next_state, done))
                self.train_model()

                prev_state = next_state
                self.total_steps += 1

                if t % C == 0:
                    self.Q_prime.load_state_dict(self.Q_policy.state_dict())

                if done:
                    break

            self.rewards.append(ep_reward)
            self.init_epsilon = max(min_epsilon, self.init_epsilon * epsilon_decay_factor)
            self.epsilon_arr.append(self.init_epsilon)
            print(f"Episode {episode}, Reward: {ep_reward}, Epsilon: {self.init_epsilon}")

        print("Training complete.")
        return self.rewards

dir_to_save_data = "/home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/"

env = GridEnvironment(max_timesteps=500)
dueling_dqn_agent = DuelingDQN(env)
dueling_training_rewards = dueling_dqn_agent.train()

plt.figure(1)
plt.plot(dueling_dqn_agent.rewards)
save_plot_as_img('dueling_dqn_warehouse_robot_reward_per_episode.png', dir_to_save_data)

plt.figure(2)
plt.plot(dueling_dqn_agent.epsilon_arr)
save_plot_as_img('dueling_dqn_warehouse_robot_epsilon_decay.png', dir_to_save_data)
# Out:
# Episode 0, Reward: -1675, Epsilon: 0.998
# Episode 1, Reward: -2350, Epsilon: 0.996004
# Episode 2, Reward: -1275, Epsilon: 0.994011992
# Episode 3, Reward: -1375, Epsilon: 0.992023968016
# Episode 4, Reward: -2775, Epsilon: 0.990039920079968
# Episode 5, Reward: -1250, Epsilon: 0.9880598402398081
# Episode 6, Reward: -1200, Epsilon: 0.9860837205593285
# Episode 7, Reward: -1250, Epsilon: 0.9841115531182099
# Episode 8, Reward: -4825, Epsilon: 0.9821433300119734
# Episode 9, Reward: -1475, Epsilon: 0.9801790433519495
# Episode 10, Reward: -1275, Epsilon: 0.9782186852652456
# Episode 11, Reward: -1925, Epsilon: 0.976262247894715
# Episode 12, Reward: -3025, Epsilon: 0.9743097233989256
# Episode 13, Reward: -1375, Epsilon: 0.9723611039521278
# Episode 14, Reward: -3975, Epsilon: 0.9704163817442236
# Episode 15, Reward: -500, Epsilon: 0.9684755489807352
# Episode 16, Reward: -2250, Epsilon: 0.9665385978827737
# Episode 17, Reward: -1275, Epsilon: 0.9646055206870082
# Episode 18, Reward: -1275, Epsilon: 0.9626763096456342
# Episode 19, Reward: -2825, Epsilon: 0.9607509570263429
# Episode 20, Reward: -1725, Epsilon: 0.9588294551122902
# Episode 21, Reward: -2125, Epsilon: 0.9569117962020657
# Episode 22, Reward: -1250, Epsilon: 0.9549979726096616
# Episode 23, Reward: -1275, Epsilon: 0.9530879766644422
# Episode 24, Reward: -5000, Epsilon: 0.9511818007111134
# Episode 25, Reward: -525, Epsilon: 0.9492794371096911
# Episode 26, Reward: -250, Epsilon: 0.9473808782354717
# Episode 27, Reward: -2400, Epsilon: 0.9454861164790007
# Episode 28, Reward: -475, Epsilon: 0.9435951442460427
# Episode 29, Reward: -1275, Epsilon: 0.9417079539575507
# Episode 30, Reward: -1550, Epsilon: 0.9398245380496356
# Episode 31, Reward: -1250, Epsilon: 0.9379448889735363
# Episode 32, Reward: -1075, Epsilon: 0.9360689991955893
# Episode 33, Reward: -1975, Epsilon: 0.9341968611971981
# Episode 34, Reward: -1275, Epsilon: 0.9323284674748037
# Episode 35, Reward: -1275, Epsilon: 0.930463810539854
# Episode 36, Reward: -1475, Epsilon: 0.9286028829187744
# Episode 37, Reward: -1325, Epsilon: 0.9267456771529368
# Episode 38, Reward: -1200, Epsilon: 0.9248921857986309
# Episode 39, Reward: -1275, Epsilon: 0.9230424014270336
# Episode 40, Reward: -2200, Epsilon: 0.9211963166241796
# Episode 41, Reward: -1275, Epsilon: 0.9193539239909312
# Episode 42, Reward: -2050, Epsilon: 0.9175152161429493
# Episode 43, Reward: -325, Epsilon: 0.9156801857106633
# Episode 44, Reward: -1050, Epsilon: 0.913848825339242
# Episode 45, Reward: -1925, Epsilon: 0.9120211276885636
# Episode 46, Reward: -1275, Epsilon: 0.9101970854331864
# Episode 47, Reward: -1000, Epsilon: 0.9083766912623201
# Episode 48, Reward: 24, Epsilon: 0.9065599378797955
# Episode 49, Reward: -3100, Epsilon: 0.9047468180040359
# Episode 50, Reward: -1575, Epsilon: 0.9029373243680279
# Episode 51, Reward: -1425, Epsilon: 0.9011314497192918
# Episode 52, Reward: -2100, Epsilon: 0.8993291868198532
# Episode 53, Reward: -1025, Epsilon: 0.8975305284462135
# Episode 54, Reward: -1200, Epsilon: 0.8957354673893211
# Episode 55, Reward: -853, Epsilon: 0.8939439964545425
# Episode 56, Reward: -561, Epsilon: 0.8921561084616334
# Episode 57, Reward: -1250, Epsilon: 0.8903717962447101
# Episode 58, Reward: -75, Epsilon: 0.8885910526522206
# Episode 59, Reward: -1278, Epsilon: 0.8868138705469162
# Episode 60, Reward: -1400, Epsilon: 0.8850402428058224
# Episode 61, Reward: -2375, Epsilon: 0.8832701623202107
# Episode 62, Reward: -2925, Epsilon: 0.8815036219955703
# Episode 63, Reward: -1275, Epsilon: 0.8797406147515792
# Episode 64, Reward: -1075, Epsilon: 0.877981133522076
# Episode 65, Reward: -150, Epsilon: 0.8762251712550319
# Episode 66, Reward: -1250, Epsilon: 0.8744727209125218
# Episode 67, Reward: -175, Epsilon: 0.8727237754706968
# Episode 68, Reward: -225, Epsilon: 0.8709783279197554
# Episode 69, Reward: -616, Epsilon: 0.8692363712639158
# Episode 70, Reward: -1100, Epsilon: 0.867497898521388
# Episode 71, Reward: -1275, Epsilon: 0.8657629027243453
# Episode 72, Reward: -1200, Epsilon: 0.8640313769188966
# Episode 73, Reward: -1700, Epsilon: 0.8623033141650589
# Episode 74, Reward: 19, Epsilon: 0.8605787075367288
# Episode 75, Reward: -4725, Epsilon: 0.8588575501216553
# Episode 76, Reward: -1250, Epsilon: 0.857139835021412
# Episode 77, Reward: -3400, Epsilon: 0.8554255553513692
# Episode 78, Reward: -2300, Epsilon: 0.8537147042406664
# Episode 79, Reward: -2300, Epsilon: 0.8520072748321851
# Episode 80, Reward: -1275, Epsilon: 0.8503032602825207
# Episode 81, Reward: -4975, Epsilon: 0.8486026537619556
# Episode 82, Reward: -700, Epsilon: 0.8469054484544317
# Episode 83, Reward: -1675, Epsilon: 0.8452116375575228
# Episode 84, Reward: -1075, Epsilon: 0.8435212142824078
# Episode 85, Reward: -1275, Epsilon: 0.841834171853843
# Episode 86, Reward: -1825, Epsilon: 0.8401505035101353
# Episode 87, Reward: -1275, Epsilon: 0.838470202503115
# Episode 88, Reward: -2475, Epsilon: 0.8367932620981088
# Episode 89, Reward: 290, Epsilon: 0.8351196755739125
# Episode 90, Reward: -1850, Epsilon: 0.8334494362227647
# Episode 91, Reward: -1425, Epsilon: 0.8317825373503192
# Episode 92, Reward: -1325, Epsilon: 0.8301189722756185
# Episode 93, Reward: -1350, Epsilon: 0.8284587343310672
# Episode 94, Reward: -2125, Epsilon: 0.8268018168624051
# Episode 95, Reward: -600, Epsilon: 0.8251482132286803
# Episode 96, Reward: -2000, Epsilon: 0.823497916802223
# Episode 97, Reward: -1231, Epsilon: 0.8218509209686186
# Episode 98, Reward: -1275, Epsilon: 0.8202072191266814
# Episode 99, Reward: -1050, Epsilon: 0.818566804688428
# Episode 100, Reward: -3900, Epsilon: 0.8169296710790511
# Episode 101, Reward: -5525, Epsilon: 0.815295811736893
# Episode 102, Reward: -650, Epsilon: 0.8136652201134192
# Episode 103, Reward: -1200, Epsilon: 0.8120378896731923
# Episode 104, Reward: -1250, Epsilon: 0.8104138138938459
# Episode 105, Reward: -850, Epsilon: 0.8087929862660582
# Episode 106, Reward: 347, Epsilon: 0.8071754002935261
# Episode 107, Reward: -261, Epsilon: 0.805561049492939
# Episode 108, Reward: -800, Epsilon: 0.8039499273939532
# Episode 109, Reward: -1275, Epsilon: 0.8023420275391653
# Episode 110, Reward: -1275, Epsilon: 0.800737343484087
# Episode 111, Reward: -1246, Epsilon: 0.7991358687971188
# Episode 112, Reward: -1275, Epsilon: 0.7975375970595246
# Episode 113, Reward: -1175, Epsilon: 0.7959425218654056
# Episode 114, Reward: -800, Epsilon: 0.7943506368216747
# Episode 115, Reward: -1725, Epsilon: 0.7927619355480314
# Episode 116, Reward: -1275, Epsilon: 0.7911764116769353
# Episode 117, Reward: -2300, Epsilon: 0.7895940588535815
# Episode 118, Reward: -1078, Epsilon: 0.7880148707358743
# Episode 119, Reward: -1925, Epsilon: 0.7864388409944025
# Episode 120, Reward: -325, Epsilon: 0.7848659633124138
# Episode 121, Reward: -600, Epsilon: 0.783296231385789
# Episode 122, Reward: 129, Epsilon: 0.7817296389230174
# Episode 123, Reward: -940, Epsilon: 0.7801661796451713
# Episode 124, Reward: -1375, Epsilon: 0.778605847285881
# Episode 125, Reward: 197, Epsilon: 0.7770486355913092
# Episode 126, Reward: -3475, Epsilon: 0.7754945383201266
# Episode 127, Reward: -1175, Epsilon: 0.7739435492434863
# Episode 128, Reward: 190, Epsilon: 0.7723956621449993
# Episode 129, Reward: -1425, Epsilon: 0.7708508708207094
# Episode 130, Reward: -3353, Epsilon: 0.769309169079068
# Episode 131, Reward: -3225, Epsilon: 0.7677705507409098
# Episode 132, Reward: -450, Epsilon: 0.766235009639428
# Episode 133, Reward: -1275, Epsilon: 0.7647025396201492
# Episode 134, Reward: 99, Epsilon: 0.763173134540909
# Episode 135, Reward: -1850, Epsilon: 0.7616467882718272
# Episode 136, Reward: -1150, Epsilon: 0.7601234946952835
# Episode 137, Reward: -1200, Epsilon: 0.7586032477058929
# Episode 138, Reward: -1275, Epsilon: 0.7570860412104812
# Episode 139, Reward: -150, Epsilon: 0.7555718691280602
# Episode 140, Reward: -500, Epsilon: 0.7540607253898041
# Episode 141, Reward: -1000, Epsilon: 0.7525526039390245
# Episode 142, Reward: -678, Epsilon: 0.7510474987311464
# Episode 143, Reward: -1275, Epsilon: 0.7495454037336841
# Episode 144, Reward: -1275, Epsilon: 0.7480463129262167
# Episode 145, Reward: -900, Epsilon: 0.7465502203003642
# Episode 146, Reward: -375, Epsilon: 0.7450571198597635
# Episode 147, Reward: -800, Epsilon: 0.743567005620044
# Episode 148, Reward: -1775, Epsilon: 0.7420798716088038
# Episode 149, Reward: -75, Epsilon: 0.7405957118655863
# Episode 150, Reward: -225, Epsilon: 0.7391145204418551
# Episode 151, Reward: -350, Epsilon: 0.7376362914009714
# Episode 152, Reward: -275, Epsilon: 0.7361610188181695
# Episode 153, Reward: -575, Epsilon: 0.7346886967805332
# Episode 154, Reward: -375, Epsilon: 0.733219319386972
# Episode 155, Reward: -345, Epsilon: 0.7317528807481981
# Episode 156, Reward: -175, Epsilon: 0.7302893749867018
# Episode 157, Reward: -475, Epsilon: 0.7288287962367284
# Episode 158, Reward: -853, Epsilon: 0.727371138644255
# Episode 159, Reward: 55, Epsilon: 0.7259163963669665
# Episode 160, Reward: -2275, Epsilon: 0.7244645635742325
# Episode 161, Reward: -725, Epsilon: 0.723015634447084
# Episode 162, Reward: -1375, Epsilon: 0.7215696031781899
# Episode 163, Reward: -1275, Epsilon: 0.7201264639718334
# Episode 164, Reward: -153, Epsilon: 0.7186862110438897
# Episode 165, Reward: -606, Epsilon: 0.717248838621802
# Episode 166, Reward: -600, Epsilon: 0.7158143409445584
# Episode 167, Reward: -605, Epsilon: 0.7143827122626694
# Episode 168, Reward: -235, Epsilon: 0.7129539468381441
# Episode 169, Reward: 279, Epsilon: 0.7115280389444678
# Episode 170, Reward: -1626, Epsilon: 0.7101049828665789
# Episode 171, Reward: -325, Epsilon: 0.7086847729008457
# Episode 172, Reward: -721, Epsilon: 0.707267403355044
# Episode 173, Reward: -575, Epsilon: 0.705852868548334
# Episode 174, Reward: 170, Epsilon: 0.7044411628112373
# Episode 175, Reward: -3650, Epsilon: 0.7030322804856147
# Episode 176, Reward: 284, Epsilon: 0.7016262159246435
# Episode 177, Reward: 349, Epsilon: 0.7002229634927942
# Episode 178, Reward: 350, Epsilon: 0.6988225175658086
# Episode 179, Reward: -75, Epsilon: 0.697424872530677
# Episode 180, Reward: 322, Epsilon: 0.6960300227856157
# Episode 181, Reward: -815, Epsilon: 0.6946379627400444
# Episode 182, Reward: -225, Epsilon: 0.6932486868145643
# Episode 183, Reward: -1250, Epsilon: 0.6918621894409351
# Episode 184, Reward: 284, Epsilon: 0.6904784650620532
# Episode 185, Reward: -1150, Epsilon: 0.6890975081319292
# Episode 186, Reward: -400, Epsilon: 0.6877193131156653
# Episode 187, Reward: -150, Epsilon: 0.6863438744894339
# Episode 188, Reward: -150, Epsilon: 0.684971186740455
# Episode 189, Reward: -1150, Epsilon: 0.6836012443669741
# Episode 190, Reward: 230, Epsilon: 0.6822340418782402
# Episode 191, Reward: 269, Epsilon: 0.6808695737944838
# Episode 192, Reward: -2225, Epsilon: 0.6795078346468948
# Episode 193, Reward: 224, Epsilon: 0.678148818977601
# Episode 194, Reward: 344, Epsilon: 0.6767925213396458
# Episode 195, Reward: -1700, Epsilon: 0.6754389362969666
# Episode 196, Reward: -416, Epsilon: 0.6740880584243727
# Episode 197, Reward: -15, Epsilon: 0.6727398823075239
# Episode 198, Reward: -2025, Epsilon: 0.6713944025429088
# Episode 199, Reward: -2450, Epsilon: 0.670051613737823
# Episode 200, Reward: 297, Epsilon: 0.6687115105103473
# Episode 201, Reward: -106, Epsilon: 0.6673740874893266
# Episode 202, Reward: 260, Epsilon: 0.6660393393143479
# Episode 203, Reward: -810, Epsilon: 0.6647072606357192
# Episode 204, Reward: 325, Epsilon: 0.6633778461144477
# Episode 205, Reward: 294, Epsilon: 0.6620510904222189
# Episode 206, Reward: -1525, Epsilon: 0.6607269882413744
# Episode 207, Reward: 305, Epsilon: 0.6594055342648917
# Episode 208, Reward: -650, Epsilon: 0.6580867231963619
# Episode 209, Reward: 97, Epsilon: 0.6567705497499692
# Episode 210, Reward: -6, Epsilon: 0.6554570086504692
# Episode 211, Reward: 240, Epsilon: 0.6541460946331682
# Episode 212, Reward: -325, Epsilon: 0.6528378024439019
# Episode 213, Reward: -1440, Epsilon: 0.6515321268390141
# Episode 214, Reward: -151, Epsilon: 0.6502290625853361
# Episode 215, Reward: -466, Epsilon: 0.6489286044601654
# Episode 216, Reward: -2878, Epsilon: 0.6476307472512451
# Episode 217, Reward: 284, Epsilon: 0.6463354857567426
# Episode 218, Reward: 49, Epsilon: 0.6450428147852291
# Episode 219, Reward: 250, Epsilon: 0.6437527291556586
# Episode 220, Reward: 200, Epsilon: 0.6424652236973473
# Episode 221, Reward: -371, Epsilon: 0.6411802932499525
# Episode 222, Reward: -655, Epsilon: 0.6398979326634526
# Episode 223, Reward: 214, Epsilon: 0.6386181367981257
# Episode 224, Reward: -1831, Epsilon: 0.6373409005245295
# Episode 225, Reward: 329, Epsilon: 0.6360662187234805
# Episode 226, Reward: -106, Epsilon: 0.6347940862860335
# Episode 227, Reward: -226, Epsilon: 0.6335244981134615
# Episode 228, Reward: 280, Epsilon: 0.6322574491172346
# Episode 229, Reward: 295, Epsilon: 0.6309929342190002
# Episode 230, Reward: -971, Epsilon: 0.6297309483505622
# Episode 231, Reward: -106, Epsilon: 0.6284714864538611
# Episode 232, Reward: -695, Epsilon: 0.6272145434809534
# Episode 233, Reward: 280, Epsilon: 0.6259601143939915
# Episode 234, Reward: -320, Epsilon: 0.6247081941652035
# Episode 235, Reward: -800, Epsilon: 0.6234587777768731
# Episode 236, Reward: 272, Epsilon: 0.6222118602213194
# Episode 237, Reward: -75, Epsilon: 0.6209674365008767
# Episode 238, Reward: -4170, Epsilon: 0.619725501627875
# Episode 239, Reward: -775, Epsilon: 0.6184860506246193
# Episode 240, Reward: -125, Epsilon: 0.61724907852337
# Episode 241, Reward: -325, Epsilon: 0.6160145803663232
# Episode 242, Reward: -1000, Epsilon: 0.6147825512055906
# Episode 243, Reward: -1100, Epsilon: 0.6135529861031793
# Episode 244, Reward: -100, Epsilon: 0.612325880130973
# Episode 245, Reward: -1250, Epsilon: 0.611101228370711
# Episode 246, Reward: -735, Epsilon: 0.6098790259139696
# Episode 247, Reward: -1050, Epsilon: 0.6086592678621416
# Episode 248, Reward: -750, Epsilon: 0.6074419493264174
# Episode 249, Reward: -2475, Epsilon: 0.6062270654277645
# Episode 250, Reward: -75, Epsilon: 0.6050146112969089
# Episode 251, Reward: -1200, Epsilon: 0.6038045820743151
# Episode 252, Reward: -1275, Epsilon: 0.6025969729101665
# Episode 253, Reward: -403, Epsilon: 0.6013917789643461
# Episode 254, Reward: -4575, Epsilon: 0.6001889954064175
# Episode 255, Reward: 230, Epsilon: 0.5989886174156046
# Episode 256, Reward: -180, Epsilon: 0.5977906401807734
# Episode 257, Reward: 294, Epsilon: 0.5965950589004119
# Episode 258, Reward: 279, Epsilon: 0.595401868782611
# Episode 259, Reward: -1200, Epsilon: 0.5942110650450458
# Episode 260, Reward: -1200, Epsilon: 0.5930226429149558
# Episode 261, Reward: -703, Epsilon: 0.5918365976291259
# Episode 262, Reward: 120, Epsilon: 0.5906529244338676
# Episode 263, Reward: -150, Epsilon: 0.5894716185849999
# Episode 264, Reward: -240, Epsilon: 0.5882926753478298
# Episode 265, Reward: 274, Epsilon: 0.5871160899971342
# Episode 266, Reward: -725, Epsilon: 0.5859418578171399
# Episode 267, Reward: -1051, Epsilon: 0.5847699741015057
# Episode 268, Reward: 225, Epsilon: 0.5836004341533026
# Episode 269, Reward: 104, Epsilon: 0.5824332332849961
# Episode 270, Reward: -378, Epsilon: 0.5812683668184261
# Episode 271, Reward: 270, Epsilon: 0.5801058300847892
# Episode 272, Reward: -1250, Epsilon: 0.5789456184246197
# Episode 273, Reward: -1703, Epsilon: 0.5777877271877704
# Episode 274, Reward: 44, Epsilon: 0.5766321517333949
# Episode 275, Reward: -390, Epsilon: 0.5754788874299281
# Episode 276, Reward: -1078, Epsilon: 0.5743279296550683
# Episode 277, Reward: -181, Epsilon: 0.5731792737957582
# Episode 278, Reward: 289, Epsilon: 0.5720329152481667
# Episode 279, Reward: 230, Epsilon: 0.5708888494176704
# Episode 280, Reward: -150, Epsilon: 0.569747071718835
# Episode 281, Reward: -211, Epsilon: 0.5686075775753973
# Episode 282, Reward: -500, Epsilon: 0.5674703624202465
# Episode 283, Reward: 4, Epsilon: 0.5663354216954061
# Episode 284, Reward: 284, Epsilon: 0.5652027508520152
# Episode 285, Reward: 295, Epsilon: 0.5640723453503111
# Episode 286, Reward: 347, Epsilon: 0.5629442006596105
# Episode 287, Reward: 20, Epsilon: 0.5618183122582913
# Episode 288, Reward: 344, Epsilon: 0.5606946756337747
# Episode 289, Reward: -778, Epsilon: 0.5595732862825071
# Episode 290, Reward: 135, Epsilon: 0.5584541397099421
# Episode 291, Reward: -175, Epsilon: 0.5573372314305222
# Episode 292, Reward: 169, Epsilon: 0.5562225569676611
# Episode 293, Reward: 305, Epsilon: 0.5551101118537257
# Episode 294, Reward: 147, Epsilon: 0.5539998916300183
# Episode 295, Reward: 220, Epsilon: 0.5528918918467582
# Episode 296, Reward: 295, Epsilon: 0.5517861080630647
# Episode 297, Reward: -545, Epsilon: 0.5506825358469386
# Episode 298, Reward: 79, Epsilon: 0.5495811707752447
# Episode 299, Reward: -6, Epsilon: 0.5484820084336942
# Episode 300, Reward: -176, Epsilon: 0.5473850444168268
# Episode 301, Reward: 274, Epsilon: 0.5462902743279932
# Episode 302, Reward: 285, Epsilon: 0.5451976937793371
# Episode 303, Reward: 304, Epsilon: 0.5441072983917784
# Episode 304, Reward: 234, Epsilon: 0.5430190837949949
# Episode 305, Reward: -150, Epsilon: 0.5419330456274049
# Episode 306, Reward: -1225, Epsilon: 0.5408491795361501
# Episode 307, Reward: 290, Epsilon: 0.5397674811770777
# Episode 308, Reward: -200, Epsilon: 0.5386879462147236
# Episode 309, Reward: -1353, Epsilon: 0.5376105703222942
# Episode 310, Reward: -53, Epsilon: 0.5365353491816496
# Episode 311, Reward: -3075, Epsilon: 0.5354622784832863
# Episode 312, Reward: 60, Epsilon: 0.5343913539263198
# Episode 313, Reward: -125, Epsilon: 0.5333225712184672
# Episode 314, Reward: 264, Epsilon: 0.5322559260760302
# Episode 315, Reward: 110, Epsilon: 0.5311914142238782
# Episode 316, Reward: 14, Epsilon: 0.5301290313954304
# Episode 317, Reward: 97, Epsilon: 0.5290687733326396
# Episode 318, Reward: 305, Epsilon: 0.5280106357859743
# Episode 319, Reward: 259, Epsilon: 0.5269546145144024
# Episode 320, Reward: -200, Epsilon: 0.5259007052853736
# Episode 321, Reward: 284, Epsilon: 0.5248489038748029
# Episode 322, Reward: -285, Epsilon: 0.5237992060670532
# Episode 323, Reward: 259, Epsilon: 0.5227516076549191
# Episode 324, Reward: 272, Epsilon: 0.5217061044396093
# Episode 325, Reward: 234, Epsilon: 0.52066269223073
# Episode 326, Reward: 322, Epsilon: 0.5196213668462686
# Episode 327, Reward: -221, Epsilon: 0.5185821241125761
# Episode 328, Reward: 219, Epsilon: 0.5175449598643509
# Episode 329, Reward: 290, Epsilon: 0.5165098699446222
# Episode 330, Reward: 295, Epsilon: 0.515476850204733
# Episode 331, Reward: 245, Epsilon: 0.5144458965043235
# Episode 332, Reward: 195, Epsilon: 0.5134170047113148
# Episode 333, Reward: -106, Epsilon: 0.5123901707018922
# Episode 334, Reward: 319, Epsilon: 0.5113653903604884
# Episode 335, Reward: -28, Epsilon: 0.5103426595797674
# Episode 336, Reward: -203, Epsilon: 0.5093219742606079
# Episode 337, Reward: 85, Epsilon: 0.5083033303120866
# Episode 338, Reward: 247, Epsilon: 0.5072867236514624
# Episode 339, Reward: -371, Epsilon: 0.5062721502041595
# Episode 340, Reward: 209, Epsilon: 0.5052596059037512
# Episode 341, Reward: -15, Epsilon: 0.5042490866919437
# Episode 342, Reward: 297, Epsilon: 0.5032405885185598
# Episode 343, Reward: 299, Epsilon: 0.5022341073415226
# Episode 344, Reward: 347, Epsilon: 0.5012296391268396
# Episode 345, Reward: 140, Epsilon: 0.5002271798485859
# Episode 346, Reward: 245, Epsilon: 0.4992267254888887
# Episode 347, Reward: 259, Epsilon: 0.4982282720379109
# Episode 348, Reward: -1250, Epsilon: 0.4972318154938351
# Episode 349, Reward: 95, Epsilon: 0.49623735186284745
# Episode 350, Reward: 165, Epsilon: 0.49524487715912174
# Episode 351, Reward: 79, Epsilon: 0.4942543874048035
# Episode 352, Reward: 247, Epsilon: 0.4932658786299939
# Episode 353, Reward: -776, Epsilon: 0.4922793468727339
# Episode 354, Reward: -820, Epsilon: 0.4912947881789884
# Episode 355, Reward: 305, Epsilon: 0.4903121986026304
# Episode 356, Reward: 139, Epsilon: 0.48933157420542517
# Episode 357, Reward: 322, Epsilon: 0.48835291105701434
# Episode 358, Reward: -76, Epsilon: 0.48737620523490033
# Episode 359, Reward: -325, Epsilon: 0.48640145282443054
# Episode 360, Reward: -2300, Epsilon: 0.48542864991878165
# Episode 361, Reward: -75, Epsilon: 0.48445779261894406
# Episode 362, Reward: 294, Epsilon: 0.4834888770337062
# Episode 363, Reward: 299, Epsilon: 0.4825218992796388
# Episode 364, Reward: -978, Epsilon: 0.4815568554810795
# Episode 365, Reward: -1875, Epsilon: 0.4805937417701174
# Episode 366, Reward: 294, Epsilon: 0.47963255428657714
# Episode 367, Reward: 315, Epsilon: 0.478673289178004
# Episode 368, Reward: 314, Epsilon: 0.477715942599648
# Episode 369, Reward: 299, Epsilon: 0.4767605107144487
# Episode 370, Reward: 259, Epsilon: 0.4758069896930198
# Episode 371, Reward: 150, Epsilon: 0.4748553757136338
# Episode 372, Reward: -101, Epsilon: 0.47390566496220654
# Episode 373, Reward: 214, Epsilon: 0.47295785363228215
# Episode 374, Reward: -136, Epsilon: 0.4720119379250176
# Episode 375, Reward: -56, Epsilon: 0.4710679140491676
# Episode 376, Reward: 204, Epsilon: 0.47012577822106927
# Episode 377, Reward: 272, Epsilon: 0.46918552666462715
# Episode 378, Reward: 324, Epsilon: 0.46824715561129787
# Episode 379, Reward: 279, Epsilon: 0.46731066130007526
# Episode 380, Reward: -226, Epsilon: 0.4663760399774751
# Episode 381, Reward: 295, Epsilon: 0.46544328789752015
# Episode 382, Reward: 310, Epsilon: 0.4645124013217251
# Episode 383, Reward: 314, Epsilon: 0.46358337651908166
# Episode 384, Reward: 280, Epsilon: 0.4626562097660435
# Episode 385, Reward: 275, Epsilon: 0.4617308973465114
# Episode 386, Reward: 329, Epsilon: 0.46080743555181836
# Episode 387, Reward: 280, Epsilon: 0.4598858206807147
# Episode 388, Reward: 250, Epsilon: 0.4589660490393533
# Episode 389, Reward: 122, Epsilon: 0.45804811694127456
# Episode 390, Reward: 245, Epsilon: 0.457132020707392
# Episode 391, Reward: -1200, Epsilon: 0.45621775666597725
# Episode 392, Reward: 264, Epsilon: 0.45530532115264527
# Episode 393, Reward: 272, Epsilon: 0.45439471051033997
# Episode 394, Reward: 169, Epsilon: 0.4534859210893193
# Episode 395, Reward: 329, Epsilon: 0.45257894924714065
# Episode 396, Reward: 22, Epsilon: 0.4516737913486464
# Episode 397, Reward: 272, Epsilon: 0.4507704437659491
# Episode 398, Reward: -491, Epsilon: 0.4498689028784172
# Episode 399, Reward: 264, Epsilon: 0.4489691650726603
# Episode 400, Reward: 272, Epsilon: 0.448071226742515
# Episode 401, Reward: 90, Epsilon: 0.44717508428902997
# Episode 402, Reward: 245, Epsilon: 0.4462807341204519
# Episode 403, Reward: 265, Epsilon: 0.445388172652211
# Episode 404, Reward: -46, Epsilon: 0.44449739630690654
# Episode 405, Reward: 247, Epsilon: 0.4436084015142927
# Episode 406, Reward: 315, Epsilon: 0.4427211847112641
# Episode 407, Reward: 272, Epsilon: 0.4418357423418416
# Episode 408, Reward: 310, Epsilon: 0.44095207085715793
# Episode 409, Reward: 100, Epsilon: 0.44007016671544363
# Episode 410, Reward: 154, Epsilon: 0.43919002638201277
# Episode 411, Reward: 245, Epsilon: 0.43831164632924874
# Episode 412, Reward: -1875, Epsilon: 0.43743502303659026
# Episode 413, Reward: 270, Epsilon: 0.4365601529905171
# Episode 414, Reward: 324, Epsilon: 0.43568703268453607
# Episode 415, Reward: 197, Epsilon: 0.434815658619167
# Episode 416, Reward: 335, Epsilon: 0.43394602730192866
# Episode 417, Reward: 59, Epsilon: 0.4330781352473248
# Episode 418, Reward: -166, Epsilon: 0.43221197897683017
# Episode 419, Reward: -605, Epsilon: 0.4313475550188765
# Episode 420, Reward: 300, Epsilon: 0.4304848599088387
# Episode 421, Reward: -490, Epsilon: 0.42962389018902103
# Episode 422, Reward: 205, Epsilon: 0.428764642408643
# Episode 423, Reward: 195, Epsilon: 0.4279071131238257
# Episode 424, Reward: 249, Epsilon: 0.42705129889757804
# Episode 425, Reward: -1031, Epsilon: 0.42619719629978287
# Episode 426, Reward: 222, Epsilon: 0.4253448019071833
# Episode 427, Reward: 195, Epsilon: 0.424494112303369
# Episode 428, Reward: 269, Epsilon: 0.42364512407876226
# Episode 429, Reward: 130, Epsilon: 0.4227978338306047
# Episode 430, Reward: 335, Epsilon: 0.42195223816294347
# Episode 431, Reward: -403, Epsilon: 0.4211083336866176
# Episode 432, Reward: 230, Epsilon: 0.4202661170192444
# Episode 433, Reward: 310, Epsilon: 0.41942558478520586
# Episode 434, Reward: -286, Epsilon: 0.4185867336156355
# Episode 435, Reward: 239, Epsilon: 0.4177495601484042
# Episode 436, Reward: 25, Epsilon: 0.4169140610281074
# Episode 437, Reward: 314, Epsilon: 0.4160802329060512
# Episode 438, Reward: 22, Epsilon: 0.4152480724402391
# Episode 439, Reward: 254, Epsilon: 0.41441757629535864
# Episode 440, Reward: -15, Epsilon: 0.4135887411427679
# Episode 441, Reward: -2356, Epsilon: 0.41276156366048233
# Episode 442, Reward: -1125, Epsilon: 0.41193604053316135
# Episode 443, Reward: 197, Epsilon: 0.41111216845209503
# Episode 444, Reward: 347, Epsilon: 0.4102899441151908
# Episode 445, Reward: 259, Epsilon: 0.40946936422696045
# Episode 446, Reward: 245, Epsilon: 0.40865042549850655
# Episode 447, Reward: -15, Epsilon: 0.40783312464750954
# Episode 448, Reward: 295, Epsilon: 0.4070174583982145
# Episode 449, Reward: 229, Epsilon: 0.4062034234814181
# Episode 450, Reward: 295, Epsilon: 0.40539101663445526
# Episode 451, Reward: 295, Epsilon: 0.40458023460118636
# Episode 452, Reward: -520, Epsilon: 0.403771074131984
# Episode 453, Reward: 245, Epsilon: 0.40296353198372004
# Episode 454, Reward: 305, Epsilon: 0.4021576049197526
# Episode 455, Reward: 290, Epsilon: 0.40135328970991313
# Episode 456, Reward: 245, Epsilon: 0.4005505831304933
# Episode 457, Reward: 222, Epsilon: 0.3997494819642323
# Episode 458, Reward: -100, Epsilon: 0.3989499830003039
# Episode 459, Reward: -455, Epsilon: 0.3981520830343033
# Episode 460, Reward: -1250, Epsilon: 0.39735577886823464
# Episode 461, Reward: 340, Epsilon: 0.39656106731049817
# Episode 462, Reward: 259, Epsilon: 0.39576794517587716
# Episode 463, Reward: 195, Epsilon: 0.3949764092855254
# Episode 464, Reward: 214, Epsilon: 0.3941864564669544
# Episode 465, Reward: 55, Epsilon: 0.39339808355402045
# Episode 466, Reward: 245, Epsilon: 0.3926112873869124
# Episode 467, Reward: 254, Epsilon: 0.3918260648121386
# Episode 468, Reward: 304, Epsilon: 0.39104241268251433
# Episode 469, Reward: 275, Epsilon: 0.3902603278571493
# Episode 470, Reward: -75, Epsilon: 0.389479807201435
# Episode 471, Reward: -28, Epsilon: 0.3887008475870321
# Episode 472, Reward: -175, Epsilon: 0.38792344589185807
# Episode 473, Reward: 349, Epsilon: 0.38714759900007434
# Episode 474, Reward: -240, Epsilon: 0.3863733038020742
# Episode 475, Reward: 305, Epsilon: 0.38560055719447006
# Episode 476, Reward: 314, Epsilon: 0.3848293560800811
# Episode 477, Reward: 179, Epsilon: 0.38405969736792095
# Episode 478, Reward: 347, Epsilon: 0.3832915779731851
# Episode 479, Reward: 295, Epsilon: 0.38252499481723873
# Episode 480, Reward: -75, Epsilon: 0.3817599448276042
# Episode 481, Reward: -125, Epsilon: 0.380996424937949
# Episode 482, Reward: 259, Epsilon: 0.3802344320880731
# Episode 483, Reward: 147, Epsilon: 0.379473963223897
# Episode 484, Reward: 119, Epsilon: 0.37871501529744916
# Episode 485, Reward: 314, Epsilon: 0.37795758526685425
# Episode 486, Reward: 245, Epsilon: 0.37720167009632055
# Episode 487, Reward: 314, Epsilon: 0.3764472667561279
# Episode 488, Reward: -281, Epsilon: 0.37569437222261565
# Episode 489, Reward: 344, Epsilon: 0.3749429834781704
# Episode 490, Reward: 272, Epsilon: 0.37419309751121405
# Episode 491, Reward: 239, Epsilon: 0.3734447113161916
# Episode 492, Reward: 310, Epsilon: 0.3726978218935592
# Episode 493, Reward: 47, Epsilon: 0.3719524262497721
# Episode 494, Reward: 305, Epsilon: 0.37120852139727256
# Episode 495, Reward: -616, Epsilon: 0.370466104354478
# Episode 496, Reward: 319, Epsilon: 0.36972517214576905
# Episode 497, Reward: -1, Epsilon: 0.36898572180147754
# Episode 498, Reward: 247, Epsilon: 0.3682477503578746
# Episode 499, Reward: -75, Epsilon: 0.36751125485715885
# Episode 500, Reward: 344, Epsilon: 0.36677623234744455
# Episode 501, Reward: 197, Epsilon: 0.3660426798827497
# Episode 502, Reward: 314, Epsilon: 0.3653105945229842
# Episode 503, Reward: -28, Epsilon: 0.3645799733339382
# Episode 504, Reward: 275, Epsilon: 0.3638508133872703
# Episode 505, Reward: 5, Epsilon: 0.3631231117604958
# Episode 506, Reward: 305, Epsilon: 0.3623968655369748
# Episode 507, Reward: -405, Epsilon: 0.3616720718059009
# Episode 508, Reward: -3275, Epsilon: 0.3609487276622891
# Episode 509, Reward: -153, Epsilon: 0.3602268302069645
# Episode 510, Reward: -75, Epsilon: 0.35950637654655054
# Episode 511, Reward: -1275, Epsilon: 0.35878736379345744
# Episode 512, Reward: 295, Epsilon: 0.3580697890658705
# Episode 513, Reward: 285, Epsilon: 0.35735364948773873
# Episode 514, Reward: 289, Epsilon: 0.35663894218876324
# Episode 515, Reward: 335, Epsilon: 0.3559256643043857
# Episode 516, Reward: 322, Epsilon: 0.3552138129757769
# Episode 517, Reward: 272, Epsilon: 0.35450338534982534
# Episode 518, Reward: 325, Epsilon: 0.3537943785791257
# Episode 519, Reward: 94, Epsilon: 0.35308678982196745
# Episode 520, Reward: -1325, Epsilon: 0.35238061624232353
# Episode 521, Reward: -150, Epsilon: 0.3516758550098389
# Episode 522, Reward: 324, Epsilon: 0.3509725032998192
# Episode 523, Reward: 259, Epsilon: 0.35027055829321957
# Episode 524, Reward: -125, Epsilon: 0.3495700171766331
# Episode 525, Reward: 299, Epsilon: 0.3488708771422798
# Episode 526, Reward: 340, Epsilon: 0.34817313538799527
# Episode 527, Reward: 285, Epsilon: 0.3474767891172193
# Episode 528, Reward: 240, Epsilon: 0.34678183553898484
# Episode 529, Reward: 335, Epsilon: 0.34608827186790686
# Episode 530, Reward: 305, Epsilon: 0.34539609532417104
# Episode 531, Reward: -125, Epsilon: 0.3447053031335227
# Episode 532, Reward: 295, Epsilon: 0.3440158925272557
# Episode 533, Reward: 305, Epsilon: 0.3433278607422012
# Episode 534, Reward: -175, Epsilon: 0.34264120502071677
# Episode 535, Reward: 245, Epsilon: 0.3419559226106753
# Episode 536, Reward: 209, Epsilon: 0.34127201076545394
# Episode 537, Reward: 272, Epsilon: 0.34058946674392304
# Episode 538, Reward: 289, Epsilon: 0.3399082878104352
# Episode 539, Reward: 22, Epsilon: 0.3392284712348143
# Episode 540, Reward: -1850, Epsilon: 0.33855001429234466
# Episode 541, Reward: -61, Epsilon: 0.33787291426376
# Episode 542, Reward: -290, Epsilon: 0.33719716843523245
# Episode 543, Reward: 340, Epsilon: 0.336522774098362
# Episode 544, Reward: 335, Epsilon: 0.33584972855016526
# Episode 545, Reward: 329, Epsilon: 0.33517802909306493
# Episode 546, Reward: 194, Epsilon: 0.3345076730348788
# Episode 547, Reward: 314, Epsilon: 0.33383865768880905
# Episode 548, Reward: 272, Epsilon: 0.3331709803734314
# Episode 549, Reward: 245, Epsilon: 0.3325046384126845
# Episode 550, Reward: 289, Epsilon: 0.3318396291358591
# Episode 551, Reward: 210, Epsilon: 0.3311759498775874
# Episode 552, Reward: 314, Epsilon: 0.33051359797783225
# Episode 553, Reward: 272, Epsilon: 0.3298525707818766
# Episode 554, Reward: -1275, Epsilon: 0.3291928656403128
# Episode 555, Reward: 344, Epsilon: 0.3285344799090322
# Episode 556, Reward: 322, Epsilon: 0.32787741094921413
# Episode 557, Reward: 222, Epsilon: 0.3272216561273157
# Episode 558, Reward: 272, Epsilon: 0.32656721281506107
# Episode 559, Reward: 305, Epsilon: 0.32591407838943093
# Episode 560, Reward: 314, Epsilon: 0.32526225023265204
# Episode 561, Reward: 305, Epsilon: 0.3246117257321867
# Episode 562, Reward: 259, Epsilon: 0.3239625022807223
# Episode 563, Reward: 245, Epsilon: 0.32331457727616086
# Episode 564, Reward: 160, Epsilon: 0.32266794812160854
# Episode 565, Reward: 350, Epsilon: 0.3220226122253653
# Episode 566, Reward: 260, Epsilon: 0.3213785670009146
# Episode 567, Reward: -125, Epsilon: 0.3207358098669128
# Episode 568, Reward: 272, Epsilon: 0.320094338247179
# Episode 569, Reward: -550, Epsilon: 0.31945414957068463
# Episode 570, Reward: -1025, Epsilon: 0.31881524127154326
# Episode 571, Reward: 344, Epsilon: 0.3181776107890002
# Episode 572, Reward: 222, Epsilon: 0.3175412555674222
# Episode 573, Reward: 324, Epsilon: 0.3169061730562873
# Episode 574, Reward: 245, Epsilon: 0.3162723607101747
# Episode 575, Reward: -675, Epsilon: 0.3156398159887544
# Episode 576, Reward: 294, Epsilon: 0.3150085363567769
# Episode 577, Reward: -175, Epsilon: 0.31437851928406335
# Episode 578, Reward: -75, Epsilon: 0.3137497622454952
# Episode 579, Reward: 322, Epsilon: 0.31312226272100424
# Episode 580, Reward: 314, Epsilon: 0.3124960181955622
# Episode 581, Reward: 197, Epsilon: 0.3118710261591711
# Episode 582, Reward: 335, Epsilon: 0.31124728410685276
# Episode 583, Reward: 294, Epsilon: 0.31062478953863903
# Episode 584, Reward: 280, Epsilon: 0.31000353995956176
# Episode 585, Reward: 335, Epsilon: 0.30938353287964265
# Episode 586, Reward: 314, Epsilon: 0.30876476581388335
# Episode 587, Reward: 340, Epsilon: 0.3081472362822556
# Episode 588, Reward: -100, Epsilon: 0.3075309418096911
# Episode 589, Reward: 70, Epsilon: 0.3069158799260717
# Episode 590, Reward: 272, Epsilon: 0.3063020481662196
# Episode 591, Reward: 304, Epsilon: 0.30568944406988713
# Episode 592, Reward: 344, Epsilon: 0.30507806518174735
# Episode 593, Reward: 329, Epsilon: 0.3044679090513839
# Episode 594, Reward: 245, Epsilon: 0.3038589732332811
# Episode 595, Reward: 344, Epsilon: 0.3032512552868145
# Episode 596, Reward: 259, Epsilon: 0.30264475277624087
# Episode 597, Reward: 272, Epsilon: 0.30203946327068837
# Episode 598, Reward: 234, Epsilon: 0.301435384344147
# Episode 599, Reward: 280, Epsilon: 0.3008325135754587
# Episode 600, Reward: 22, Epsilon: 0.3002308485483078
# Episode 601, Reward: 297, Epsilon: 0.2996303868512112
# Episode 602, Reward: 314, Epsilon: 0.29903112607750876
# Episode 603, Reward: 304, Epsilon: 0.29843306382535373
# Episode 604, Reward: 222, Epsilon: 0.29783619769770303
# Episode 605, Reward: 322, Epsilon: 0.2972405253023076
# Episode 606, Reward: 340, Epsilon: 0.296646044251703
# Episode 607, Reward: 222, Epsilon: 0.2960527521631996
# Episode 608, Reward: 245, Epsilon: 0.29546064665887317
# Episode 609, Reward: 264, Epsilon: 0.29486972536555545
# Episode 610, Reward: 284, Epsilon: 0.29427998591482435
# Episode 611, Reward: 349, Epsilon: 0.2936914259429947
# Episode 612, Reward: 295, Epsilon: 0.2931040430911087
# Episode 613, Reward: 325, Epsilon: 0.2925178350049265
# Episode 614, Reward: -75, Epsilon: 0.29193279933491667
# Episode 615, Reward: 294, Epsilon: 0.2913489337362468
# Episode 616, Reward: 329, Epsilon: 0.2907662358687743
# Episode 617, Reward: 272, Epsilon: 0.2901847033970368
# Episode 618, Reward: -300, Epsilon: 0.2896043339902427
# Episode 619, Reward: -386, Epsilon: 0.2890251253222622
# Episode 620, Reward: 314, Epsilon: 0.2884470750716177
# Episode 621, Reward: 79, Epsilon: 0.2878701809214745
# Episode 622, Reward: -75, Epsilon: 0.28729444055963155
# Episode 623, Reward: 314, Epsilon: 0.28671985167851227
# Episode 624, Reward: -340, Epsilon: 0.2861464119751552
# Episode 625, Reward: 204, Epsilon: 0.2855741191512049
# Episode 626, Reward: 260, Epsilon: 0.2850029709129025
# Episode 627, Reward: 314, Epsilon: 0.2844329649710767
# Episode 628, Reward: 349, Epsilon: 0.2838640990411345
# Episode 629, Reward: 245, Epsilon: 0.28329637084305226
# Episode 630, Reward: -75, Epsilon: 0.2827297781013662
# Episode 631, Reward: 344, Epsilon: 0.28216431854516344
# Episode 632, Reward: 0, Epsilon: 0.2815999899080731
# Episode 633, Reward: -11, Epsilon: 0.281036789928257
# Episode 634, Reward: 49, Epsilon: 0.2804747163484005
# Episode 635, Reward: 329, Epsilon: 0.2799137669157037
# Episode 636, Reward: -1735, Epsilon: 0.2793539393818723
# Episode 637, Reward: 350, Epsilon: 0.2787952315031086
# Episode 638, Reward: 59, Epsilon: 0.27823764104010235
# Episode 639, Reward: 22, Epsilon: 0.27768116575802215
# Episode 640, Reward: -125, Epsilon: 0.2771258034265061
# Episode 641, Reward: 22, Epsilon: 0.2765715518196531
# Episode 642, Reward: 295, Epsilon: 0.2760184087160138
# Episode 643, Reward: 264, Epsilon: 0.27546637189858175
# Episode 644, Reward: 172, Epsilon: 0.2749154391547846
# Episode 645, Reward: 245, Epsilon: 0.27436560827647505
# Episode 646, Reward: -330, Epsilon: 0.2738168770599221
# Episode 647, Reward: 322, Epsilon: 0.2732692433058022
# Episode 648, Reward: -75, Epsilon: 0.2727227048191906
# Episode 649, Reward: -100, Epsilon: 0.27217725940955223
# Episode 650, Reward: -75, Epsilon: 0.2716329048907331
# Episode 651, Reward: -75, Epsilon: 0.2710896390809516
# Episode 652, Reward: 272, Epsilon: 0.2705474598027897
# Episode 653, Reward: 314, Epsilon: 0.27000636488318414
# Episode 654, Reward: 335, Epsilon: 0.26946635215341774
# Episode 655, Reward: 85, Epsilon: 0.2689274194491109
# Episode 656, Reward: 329, Epsilon: 0.2683895646102127
# Episode 657, Reward: 314, Epsilon: 0.2678527854809923
# Episode 658, Reward: 305, Epsilon: 0.2673170799100303
# Episode 659, Reward: -106, Epsilon: 0.2667824457502102
# Episode 660, Reward: 347, Epsilon: 0.2662488808587098
# Episode 661, Reward: 265, Epsilon: 0.26571638309699236
# Episode 662, Reward: 272, Epsilon: 0.26518495033079836
# Episode 663, Reward: 245, Epsilon: 0.2646545804301368
# Episode 664, Reward: 305, Epsilon: 0.26412527126927654
# Episode 665, Reward: 284, Epsilon: 0.26359702072673796
# Episode 666, Reward: -681, Epsilon: 0.2630698266852845
# Episode 667, Reward: -65, Epsilon: 0.26254368703191394
# Episode 668, Reward: -28, Epsilon: 0.2620185996578501
# Episode 669, Reward: 259, Epsilon: 0.2614945624585344
# Episode 670, Reward: 344, Epsilon: 0.26097157333361737
# Episode 671, Reward: 295, Epsilon: 0.2604496301869501
# Episode 672, Reward: 280, Epsilon: 0.2599287309265762
# Episode 673, Reward: 272, Epsilon: 0.259408873464723
# Episode 674, Reward: 272, Epsilon: 0.25889005571779355
# Episode 675, Reward: 209, Epsilon: 0.25837227560635795
# Episode 676, Reward: 234, Epsilon: 0.25785553105514525
# Episode 677, Reward: 147, Epsilon: 0.25733981999303496
# Episode 678, Reward: 314, Epsilon: 0.2568251403530489
# Episode 679, Reward: 222, Epsilon: 0.2563114900723428
# Episode 680, Reward: 295, Epsilon: 0.25579886709219807
# Episode 681, Reward: 39, Epsilon: 0.25528726935801366
# Episode 682, Reward: 295, Epsilon: 0.25477669481929766
# Episode 683, Reward: 230, Epsilon: 0.25426714142965906
# Episode 684, Reward: -70, Epsilon: 0.25375860714679976
# Episode 685, Reward: 294, Epsilon: 0.25325108993250617
# Episode 686, Reward: 272, Epsilon: 0.25274458775264114
# Episode 687, Reward: 245, Epsilon: 0.25223909857713583
# Episode 688, Reward: 329, Epsilon: 0.25173462037998157
# Episode 689, Reward: 284, Epsilon: 0.2512311511392216
# Episode 690, Reward: 329, Epsilon: 0.25072868883694316
# Episode 691, Reward: 340, Epsilon: 0.2502272314592693
# Episode 692, Reward: -150, Epsilon: 0.24972677699635074
# Episode 693, Reward: -700, Epsilon: 0.24922732344235804
# Episode 694, Reward: -428, Epsilon: 0.24872886879547332
# Episode 695, Reward: 125, Epsilon: 0.24823141105788238
# Episode 696, Reward: 285, Epsilon: 0.2477349482357666
# Episode 697, Reward: 245, Epsilon: 0.24723947833929508
# Episode 698, Reward: 179, Epsilon: 0.2467449993826165
# Episode 699, Reward: 289, Epsilon: 0.24625150938385126
# Episode 700, Reward: 195, Epsilon: 0.24575900636508355
# Episode 701, Reward: 344, Epsilon: 0.24526748835235337
# Episode 702, Reward: -1150, Epsilon: 0.24477695337564867
# Episode 703, Reward: 335, Epsilon: 0.24428739946889738
# Episode 704, Reward: -1841, Epsilon: 0.24379882466995959
# Episode 705, Reward: 295, Epsilon: 0.24331122702061966
# Episode 706, Reward: -236, Epsilon: 0.24282460456657842
# Episode 707, Reward: 335, Epsilon: 0.24233895535744526
# Episode 708, Reward: 34, Epsilon: 0.24185427744673038
# Episode 709, Reward: 245, Epsilon: 0.24137056889183692
# Episode 710, Reward: 314, Epsilon: 0.24088782775405324
# Episode 711, Reward: 245, Epsilon: 0.24040605209854513
# Episode 712, Reward: 5, Epsilon: 0.23992523999434803
# Episode 713, Reward: 272, Epsilon: 0.23944538951435934
# Episode 714, Reward: 299, Epsilon: 0.23896649873533063
# Episode 715, Reward: 295, Epsilon: 0.23848856573785998
# Episode 716, Reward: -75, Epsilon: 0.23801158860638427
# Episode 717, Reward: 350, Epsilon: 0.2375355654291715
# Episode 718, Reward: 295, Epsilon: 0.23706049429831316
# Episode 719, Reward: 199, Epsilon: 0.23658637330971655
# Episode 720, Reward: -125, Epsilon: 0.23611320056309712
# Episode 721, Reward: 350, Epsilon: 0.2356409741619709
# Episode 722, Reward: 272, Epsilon: 0.23516969221364697
# Episode 723, Reward: 222, Epsilon: 0.2346993528292197
# Episode 724, Reward: 245, Epsilon: 0.23422995412356126
# Episode 725, Reward: 245, Epsilon: 0.23376149421531414
# Episode 726, Reward: 245, Epsilon: 0.2332939712268835
# Episode 727, Reward: 59, Epsilon: 0.23282738328442973
# Episode 728, Reward: 340, Epsilon: 0.23236172851786085
# Episode 729, Reward: 272, Epsilon: 0.23189700506082514
# Episode 730, Reward: 272, Epsilon: 0.2314332110507035
# Episode 731, Reward: 197, Epsilon: 0.23097034462860208
# Episode 732, Reward: 295, Epsilon: 0.23050840393934488
# Episode 733, Reward: 34, Epsilon: 0.2300473871314662
# Episode 734, Reward: 272, Epsilon: 0.22958729235720327
# Episode 735, Reward: 222, Epsilon: 0.22912811777248887
# Episode 736, Reward: 272, Epsilon: 0.22866986153694388
# Episode 737, Reward: 245, Epsilon: 0.22821252181387
# Episode 738, Reward: 272, Epsilon: 0.22775609677024225
# Episode 739, Reward: 259, Epsilon: 0.22730058457670177
# Episode 740, Reward: 245, Epsilon: 0.22684598340754836
# Episode 741, Reward: 272, Epsilon: 0.22639229144073325
# Episode 742, Reward: 209, Epsilon: 0.22593950685785177
# Episode 743, Reward: 272, Epsilon: 0.22548762784413606
# Episode 744, Reward: 130, Epsilon: 0.2250366525884478
# Episode 745, Reward: 234, Epsilon: 0.2245865792832709
# Episode 746, Reward: 264, Epsilon: 0.22413740612470434
# Episode 747, Reward: 259, Epsilon: 0.22368913131245494
# Episode 748, Reward: 295, Epsilon: 0.22324175304983002
# Episode 749, Reward: 234, Epsilon: 0.22279526954373036
# Episode 750, Reward: 164, Epsilon: 0.2223496790046429
# Episode 751, Reward: 324, Epsilon: 0.2219049796466336
# Episode 752, Reward: 350, Epsilon: 0.22146116968734034
# Episode 753, Reward: 347, Epsilon: 0.22101824734796566
# Episode 754, Reward: 335, Epsilon: 0.22057621085326973
# Episode 755, Reward: 295, Epsilon: 0.2201350584315632
# Episode 756, Reward: -41, Epsilon: 0.21969478831470007
# Episode 757, Reward: 350, Epsilon: 0.21925539873807068
# Episode 758, Reward: 347, Epsilon: 0.21881688794059453
# Episode 759, Reward: 340, Epsilon: 0.21837925416471335
# Episode 760, Reward: -810, Epsilon: 0.21794249565638393
# Episode 761, Reward: 340, Epsilon: 0.21750661066507115
# Episode 762, Reward: 324, Epsilon: 0.21707159744374102
# Episode 763, Reward: 340, Epsilon: 0.21663745424885353
# Episode 764, Reward: 279, Epsilon: 0.21620417934035582
# Episode 765, Reward: 295, Epsilon: 0.2157717709816751
# Episode 766, Reward: 245, Epsilon: 0.21534022743971176
# Episode 767, Reward: -75, Epsilon: 0.21490954698483233
# Episode 768, Reward: 295, Epsilon: 0.21447972789086267
# Episode 769, Reward: 0, Epsilon: 0.21405076843508095
# Episode 770, Reward: 314, Epsilon: 0.21362266689821077
# Episode 771, Reward: 350, Epsilon: 0.21319542156441434
# Episode 772, Reward: 310, Epsilon: 0.21276903072128553
# Episode 773, Reward: -125, Epsilon: 0.21234349265984295
# Episode 774, Reward: -75, Epsilon: 0.21191880567452326
# Episode 775, Reward: 344, Epsilon: 0.21149496806317422
# Episode 776, Reward: 350, Epsilon: 0.21107197812704787
# Episode 777, Reward: 340, Epsilon: 0.21064983417079378
# Episode 778, Reward: 347, Epsilon: 0.21022853450245219
# Episode 779, Reward: 214, Epsilon: 0.2098080774334473
# Episode 780, Reward: -151, Epsilon: 0.20938846127858038
# Episode 781, Reward: 230, Epsilon: 0.20896968435602323
# Episode 782, Reward: 270, Epsilon: 0.2085517449873112
# Episode 783, Reward: 347, Epsilon: 0.20813464149733657
# Episode 784, Reward: 197, Epsilon: 0.2077183722143419
# Episode 785, Reward: -75, Epsilon: 0.2073029354699132
# Episode 786, Reward: 322, Epsilon: 0.20688832959897338
# Episode 787, Reward: 234, Epsilon: 0.20647455293977543
# Episode 788, Reward: -75, Epsilon: 0.20606160383389588
# Episode 789, Reward: 64, Epsilon: 0.2056494806262281
# Episode 790, Reward: 350, Epsilon: 0.20523818166497565
# Episode 791, Reward: 329, Epsilon: 0.2048277053016457
# Episode 792, Reward: 272, Epsilon: 0.20441804989104242
# Episode 793, Reward: 350, Epsilon: 0.20400921379126033
# Episode 794, Reward: 297, Epsilon: 0.20360119536367782
# Episode 795, Reward: 272, Epsilon: 0.20319399297295046
# Episode 796, Reward: 272, Epsilon: 0.20278760498700457
# Episode 797, Reward: -1075, Epsilon: 0.20238202977703057
# Episode 798, Reward: 322, Epsilon: 0.2019772657174765
# Episode 799, Reward: 245, Epsilon: 0.20157331118604155
# Episode 800, Reward: 350, Epsilon: 0.20117016456366946
# Episode 801, Reward: 279, Epsilon: 0.20076782423454212
# Episode 802, Reward: 259, Epsilon: 0.20036628858607303
# Episode 803, Reward: 344, Epsilon: 0.19996555600890087
# Episode 804, Reward: 272, Epsilon: 0.19956562489688306
# Episode 805, Reward: -75, Epsilon: 0.1991664936470893
# Episode 806, Reward: -75, Epsilon: 0.1987681606597951
# Episode 807, Reward: -206, Epsilon: 0.19837062433847552
# Episode 808, Reward: 295, Epsilon: 0.19797388308979857
# Episode 809, Reward: 329, Epsilon: 0.19757793532361898
# Episode 810, Reward: 25, Epsilon: 0.19718277945297175
# Episode 811, Reward: -851, Epsilon: 0.1967884138940658
# Episode 812, Reward: -75, Epsilon: 0.19639483706627767
# Episode 813, Reward: 272, Epsilon: 0.1960020473921451
# Episode 814, Reward: 295, Epsilon: 0.1956100432973608
# Episode 815, Reward: 314, Epsilon: 0.19521882321076608
# Episode 816, Reward: 270, Epsilon: 0.19482838556434456
# Episode 817, Reward: 220, Epsilon: 0.1944387287932159
# Episode 818, Reward: 234, Epsilon: 0.19404985133562946
# Episode 819, Reward: 272, Epsilon: 0.1936617516329582
# Episode 820, Reward: 245, Epsilon: 0.19327442812969228
# Episode 821, Reward: 245, Epsilon: 0.1928878792734329
# Episode 822, Reward: 245, Epsilon: 0.19250210351488603
# Episode 823, Reward: 314, Epsilon: 0.19211709930785625
# Episode 824, Reward: 209, Epsilon: 0.19173286510924054
# Episode 825, Reward: 47, Epsilon: 0.19134939937902207
# Episode 826, Reward: 272, Epsilon: 0.19096670058026402
# Episode 827, Reward: 209, Epsilon: 0.1905847671791035
# Episode 828, Reward: 264, Epsilon: 0.1902035976447453
# Episode 829, Reward: 264, Epsilon: 0.1898231904494558
# Episode 830, Reward: 245, Epsilon: 0.1894435440685569
# Episode 831, Reward: 259, Epsilon: 0.1890646569804198
# Episode 832, Reward: 245, Epsilon: 0.18868652766645896
# Episode 833, Reward: 272, Epsilon: 0.18830915461112605
# Episode 834, Reward: 245, Epsilon: 0.1879325363019038
# Episode 835, Reward: 272, Epsilon: 0.18755667122929998
# Episode 836, Reward: 59, Epsilon: 0.18718155788684138
# Episode 837, Reward: 245, Epsilon: 0.1868071947710677
# Episode 838, Reward: -106, Epsilon: 0.18643358038152555
# Episode 839, Reward: 295, Epsilon: 0.1860607132207625
# Episode 840, Reward: 214, Epsilon: 0.18568859179432098
# Episode 841, Reward: 245, Epsilon: 0.18531721461073233
# Episode 842, Reward: 235, Epsilon: 0.18494658018151086
# Episode 843, Reward: 245, Epsilon: 0.18457668702114785
# Episode 844, Reward: 279, Epsilon: 0.18420753364710554
# Episode 845, Reward: 305, Epsilon: 0.18383911857981133
# Episode 846, Reward: 245, Epsilon: 0.1834714403426517
# Episode 847, Reward: 295, Epsilon: 0.1831044974619664
# Episode 848, Reward: 284, Epsilon: 0.18273828846704246
# Episode 849, Reward: 294, Epsilon: 0.18237281189010837
# Episode 850, Reward: 295, Epsilon: 0.18200806626632815
# Episode 851, Reward: 340, Epsilon: 0.1816440501337955
# Episode 852, Reward: 245, Epsilon: 0.18128076203352791
# Episode 853, Reward: 234, Epsilon: 0.18091820050946086
# Episode 854, Reward: -1590, Epsilon: 0.18055636410844195
# Episode 855, Reward: 245, Epsilon: 0.18019525138022507
# Episode 856, Reward: -701, Epsilon: 0.17983486087746461
# Episode 857, Reward: 272, Epsilon: 0.17947519115570967
# Episode 858, Reward: 264, Epsilon: 0.17911624077339824
# Episode 859, Reward: 84, Epsilon: 0.17875800829185146
# Episode 860, Reward: 147, Epsilon: 0.17840049227526775
# Episode 861, Reward: 245, Epsilon: 0.1780436912907172
# Episode 862, Reward: 272, Epsilon: 0.17768760390813576
# Episode 863, Reward: 245, Epsilon: 0.17733222870031948
# Episode 864, Reward: 285, Epsilon: 0.17697756424291883
# Episode 865, Reward: 245, Epsilon: 0.17662360911443298
# Episode 866, Reward: 279, Epsilon: 0.17627036189620413
# Episode 867, Reward: 259, Epsilon: 0.17591782117241173
# Episode 868, Reward: 247, Epsilon: 0.17556598553006691
# Episode 869, Reward: 245, Epsilon: 0.1752148535590068
# Episode 870, Reward: 272, Epsilon: 0.17486442385188877
# Episode 871, Reward: 245, Epsilon: 0.17451469500418498
# Episode 872, Reward: 295, Epsilon: 0.17416566561417662
# Episode 873, Reward: 222, Epsilon: 0.17381733428294827
# Episode 874, Reward: 272, Epsilon: 0.17346969961438236
# Episode 875, Reward: 245, Epsilon: 0.1731227602151536
# Episode 876, Reward: 284, Epsilon: 0.1727765146947233
# Episode 877, Reward: 259, Epsilon: 0.17243096166533387
# Episode 878, Reward: 245, Epsilon: 0.1720860997420032
# Episode 879, Reward: 324, Epsilon: 0.17174192754251918
# Episode 880, Reward: 74, Epsilon: 0.17139844368743415
# Episode 881, Reward: 245, Epsilon: 0.17105564680005927
# Episode 882, Reward: 245, Epsilon: 0.17071353550645915
# Episode 883, Reward: 245, Epsilon: 0.17037210843544623
# Episode 884, Reward: 245, Epsilon: 0.17003136421857534
# Episode 885, Reward: 272, Epsilon: 0.1696913014901382
# Episode 886, Reward: -75, Epsilon: 0.16935191888715792
# Episode 887, Reward: 284, Epsilon: 0.1690132150493836
# Episode 888, Reward: 295, Epsilon: 0.16867518861928482
# Episode 889, Reward: 245, Epsilon: 0.16833783824204626
# Episode 890, Reward: 340, Epsilon: 0.16800116256556216
# Episode 891, Reward: 272, Epsilon: 0.16766516024043104
# Episode 892, Reward: 314, Epsilon: 0.16732982991995018
# Episode 893, Reward: 245, Epsilon: 0.1669951702601103
# Episode 894, Reward: 245, Epsilon: 0.16666117991959006
# Episode 895, Reward: -75, Epsilon: 0.16632785755975088
# Episode 896, Reward: 245, Epsilon: 0.16599520184463137
# Episode 897, Reward: 279, Epsilon: 0.16566321144094212
# Episode 898, Reward: 245, Epsilon: 0.16533188501806023
# Episode 899, Reward: -100, Epsilon: 0.1650012212480241
# Episode 900, Reward: 314, Epsilon: 0.16467121880552807
# Episode 901, Reward: 350, Epsilon: 0.164341876367917
# Episode 902, Reward: -1078, Epsilon: 0.16401319261518116
# Episode 903, Reward: 245, Epsilon: 0.1636851662299508
# Episode 904, Reward: 259, Epsilon: 0.1633577958974909
# Episode 905, Reward: 245, Epsilon: 0.1630310803056959
# Episode 906, Reward: 347, Epsilon: 0.1627050181450845
# Episode 907, Reward: 245, Epsilon: 0.16237960810879434
# Episode 908, Reward: 259, Epsilon: 0.16205484889257676
# Episode 909, Reward: 222, Epsilon: 0.1617307391947916
# Episode 910, Reward: 259, Epsilon: 0.16140727771640204
# Episode 911, Reward: 329, Epsilon: 0.16108446316096922
# Episode 912, Reward: 234, Epsilon: 0.16076229423464727
# Episode 913, Reward: 245, Epsilon: 0.16044076964617798
# Episode 914, Reward: 222, Epsilon: 0.16011988810688563
# Episode 915, Reward: 272, Epsilon: 0.15979964833067187
# Episode 916, Reward: 245, Epsilon: 0.15948004903401053
# Episode 917, Reward: 222, Epsilon: 0.1591610889359425
# Episode 918, Reward: 245, Epsilon: 0.1588427667580706
# Episode 919, Reward: 245, Epsilon: 0.15852508122455447
# Episode 920, Reward: 314, Epsilon: 0.15820803106210535
# Episode 921, Reward: 272, Epsilon: 0.15789161499998114
# Episode 922, Reward: 272, Epsilon: 0.1575758317699812
# Episode 923, Reward: 272, Epsilon: 0.15726068010644123
# Episode 924, Reward: 272, Epsilon: 0.15694615874622836
# Episode 925, Reward: 245, Epsilon: 0.1566322664287359
# Episode 926, Reward: 245, Epsilon: 0.15631900189587844
# Episode 927, Reward: 329, Epsilon: 0.1560063638920867
# Episode 928, Reward: -5225, Epsilon: 0.15569435116430252
# Episode 929, Reward: -350, Epsilon: 0.15538296246197392
# Episode 930, Reward: -1250, Epsilon: 0.15507219653704996
# Episode 931, Reward: -225, Epsilon: 0.15476205214397584
# Episode 932, Reward: -75, Epsilon: 0.1544525280396879
# Episode 933, Reward: 314, Epsilon: 0.1541436229836085
# Episode 934, Reward: 349, Epsilon: 0.1538353357376413
# Episode 935, Reward: 347, Epsilon: 0.15352766506616602
# Episode 936, Reward: 295, Epsilon: 0.15322060973603369
# Episode 937, Reward: 322, Epsilon: 0.15291416851656162
# Episode 938, Reward: 245, Epsilon: 0.15260834017952848
# Episode 939, Reward: 305, Epsilon: 0.15230312349916944
# Episode 940, Reward: 272, Epsilon: 0.1519985172521711
# Episode 941, Reward: 329, Epsilon: 0.15169452021766675
# Episode 942, Reward: -2165, Epsilon: 0.1513911311772314
# Episode 943, Reward: 245, Epsilon: 0.15108834891487694
# Episode 944, Reward: 47, Epsilon: 0.15078617221704718
# Episode 945, Reward: 329, Epsilon: 0.1504845998726131
# Episode 946, Reward: 305, Epsilon: 0.15018363067286786
# Episode 947, Reward: 272, Epsilon: 0.1498832634115221
# Episode 948, Reward: -450, Epsilon: 0.14958349688469907
# Episode 949, Reward: -1000, Epsilon: 0.14928432989092968
# Episode 950, Reward: 259, Epsilon: 0.14898576123114782
# Episode 951, Reward: 245, Epsilon: 0.1486877897086855
# Episode 952, Reward: 272, Epsilon: 0.14839041412926815
# Episode 953, Reward: 322, Epsilon: 0.1480936333010096
# Episode 954, Reward: 259, Epsilon: 0.1477974460344076
# Episode 955, Reward: 295, Epsilon: 0.14750185114233877
# Episode 956, Reward: 272, Epsilon: 0.14720684744005408
# Episode 957, Reward: 295, Epsilon: 0.14691243374517396
# Episode 958, Reward: 245, Epsilon: 0.1466186088776836
# Episode 959, Reward: -170, Epsilon: 0.14632537165992823
# Episode 960, Reward: 209, Epsilon: 0.14603272091660838
# Episode 961, Reward: 295, Epsilon: 0.14574065547477516
# Episode 962, Reward: 245, Epsilon: 0.1454491741638256
# Episode 963, Reward: 245, Epsilon: 0.14515827581549795
# Episode 964, Reward: 297, Epsilon: 0.14486795926386695
# Episode 965, Reward: 324, Epsilon: 0.1445782233453392
# Episode 966, Reward: -75, Epsilon: 0.14428906689864854
# Episode 967, Reward: 214, Epsilon: 0.14400048876485125
# Episode 968, Reward: -2300, Epsilon: 0.14371248778732154
# Episode 969, Reward: 234, Epsilon: 0.14342506281174688
# Episode 970, Reward: 322, Epsilon: 0.1431382126861234
# Episode 971, Reward: 245, Epsilon: 0.14285193626075116
# Episode 972, Reward: 322, Epsilon: 0.14256623238822966
# Episode 973, Reward: 245, Epsilon: 0.1422810999234532
# Episode 974, Reward: 245, Epsilon: 0.1419965377236063
# Episode 975, Reward: 272, Epsilon: 0.14171254464815908
# Episode 976, Reward: 245, Epsilon: 0.14142911955886275
# Episode 977, Reward: 245, Epsilon: 0.14114626131974503
# Episode 978, Reward: 245, Epsilon: 0.14086396879710555
# Episode 979, Reward: 222, Epsilon: 0.14058224085951135
# Episode 980, Reward: 234, Epsilon: 0.14030107637779232
# Episode 981, Reward: 245, Epsilon: 0.14002047422503675
# Episode 982, Reward: 245, Epsilon: 0.13974043327658667
# Episode 983, Reward: 222, Epsilon: 0.1394609524100335
# Episode 984, Reward: 272, Epsilon: 0.13918203050521344
# Episode 985, Reward: 245, Epsilon: 0.13890366644420302
# Episode 986, Reward: 259, Epsilon: 0.13862585911131461
# Episode 987, Reward: 234, Epsilon: 0.138348607393092
# Episode 988, Reward: 245, Epsilon: 0.1380719101783058
# Episode 989, Reward: 295, Epsilon: 0.13779576635794918
# Episode 990, Reward: 245, Epsilon: 0.1375201748252333
# Episode 991, Reward: 272, Epsilon: 0.13724513447558281
# Episode 992, Reward: -1275, Epsilon: 0.13697064420663166
# Episode 993, Reward: 347, Epsilon: 0.1366967029182184
# Episode 994, Reward: 272, Epsilon: 0.13642330951238196
# Episode 995, Reward: 245, Epsilon: 0.1361504628933572
# Episode 996, Reward: 245, Epsilon: 0.13587816196757047
# Episode 997, Reward: 284, Epsilon: 0.13560640564363532
# Episode 998, Reward: 347, Epsilon: 0.13533519283234804
# Episode 999, Reward: 272, Epsilon: 0.13506452244668335
# Training complete.
# Plot saved at: /home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/dueling_dqn_warehouse_robot_reward_per_episode.png
# Plot saved at: /home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/dueling_dqn_warehouse_robot_epsilon_decay.png

# %% [markdown]
# ### Comparing the rewards obtained by vanilla DQN and Dueling DQN

# %%
plt.figure(figsize=(8, 5))
plt.plot(dqn_agent.rewards, label="Vanilla DQN")
plt.plot(dueling_dqn_agent.rewards, label="Dueling DQN")
plt.title('Training Rewards')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()

plt.tight_layout()
plt.show()

dir_to_save_data = "/home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/"
save_plot_as_img('comparing_dueling_dqn_vanilla_dqn_warehouse_robot_reward_per_episode.png', dir_to_save_data)
# Out:
# Plot saved at: /home/hamid/UB/courses/sp2025/CSE546_RL/RL/data/comparing_dueling_dqn_vanilla_dqn_warehouse_robot_reward_per_episode.png

# %%
def test(nn, num_episodes=10, max_steps=50):
    from IPython.display import clear_output
    import time
    
    rewards_all_episodes = []
    
    for episode in range(num_episodes):
        obs, info = env.reset()
        
        total_rewards = 0
        
        for step in range(max_steps):
            # Convert observation to a tensor and add batch dimension.
            obs_tensor = torch.tensor(obs, dtype=torch.float32).unsqueeze(0)
            # Compute action using the network.
            action = torch.argmax(nn(obs_tensor)).item()
            
            # Execute action.
            obs, reward, terminated, truncated, info = env.step(action)
            total_rewards += reward
            
            # Render the environment.
            env.render()
            time.sleep(.1)  # Pause briefly so updates are visible.
            clear_output(wait=True)  # Clear previous output.
            # print(obs)
            if terminated:
                break
        
        rewards_all_episodes.append(total_rewards)
    
    return rewards_all_episodes

time.sleep(1)
t = test(dueling_dqn_agent.Q_policy, num_episodes=1, max_steps=200)
plt.figure(1)
plt.plot(t)
plt.title('total reward per episode, test agent, greedy actions')
# save_plot_as_img('dqn_warehouse_robot_reward_per_episod_5episodes.png', dir_to_save_data)
# Out:
# Text(0.5, 1.0, 'total reward per episode, test agent, greedy actions')

# %%
save_path = "vanilla_dqn_gridworld.pth"
torch.save(dqn_agent.Q_policy.state_dict(), save_path)
print(f"Model saved to {save_path}")
# Out:
# Model saved to vanilla_dqn_gridworld.pth
